# %% [markdown]
# ### Original Context Prediction
#
# With original context. <br>
# But only for the questions that answer in the reduced context

# %%
original_qids =!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/logs/log_longformer_hotpotqa_reduced_train_answer_d7d5adc74a0d0b7ba99a6ee9ef19be0270b17c60_1gpu.txt" | awk -F "[:\t]" '{ sub("^[ ]+", "", $(NF-6));  print $(NF-6)}'   )

# %%
original_qids
# Out:
# ['5a8b57f25542995d1e6f1371',
#  '5a85ea095542994775f606a8',
#  '5adbf0a255429947ff17385a',
#  '5a8e3ea95542995a26add48d',
#  '5abd94525542992ac4f382d2',
#  '5a85b2d95542997b5ce40028',
#  '5a87ab905542996e4f3088c1',
#  '5a7bbb64554299042af8f7cc',
#  '5a8db19d5542994ba4e3dd00',
#  '5a7166395542994082a3e814',
#  '5a877e5d5542993e715abf7d',
#  '5ab3b0bf5542992ade7c6e39',
#  '5ab56e32554299637185c594',
#  '5ab6d09255429954757d337d',
#  '5ab3e45655429976abd1bcd4',
#  '5ab29c24554299449642c932',
#  '5ae7a8175542993210983ed8',
#  '5ae2070a5542994d89d5b313',
#  '5ae22b8d554299234fd0440f',
#  '5adf37a95542995ec70e8f97',
#  '5abd259d55429924427fcf1a',
#  '5a828c8355429966c78a6a50',
#  '5ac23ff0554299636651994d',
#  '5ae4a3265542995ad6573de5',
#  '5ae0361155429925eb1afc2c',
#  '5abc0a5d5542993f40c73c64',
#  '5a7cc50e554299452d57ba3e',
#  '5a8ef2a75542995a26add583',
#  '5a80721b554299485f5985ef',
#  '5ab51dae5542991779162d82',
#  '5a7571135542992d0ec05f98',
#  '5a7a0e1e5542990783324e1a',
# ...

# %%
original_pre_answers=!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/logs/log_longformer_hotpotqa_reduced_train_answer_d7d5adc74a0d0b7ba99a6ee9ef19be0270b17c60_1gpu.txt" |  awk -F "[:\t]" '{sub("^[ ]+", "", $(NF-3)); sub("[ ]+$", "", $(NF-3));  print $(NF-3)}'   )

# sub("^[ ]+", "") trim leading whitespace
# sub("[ ]+$", "") trim tailing whitespace

# %%
original_pre_answers
# Out:
# ['yes',
#  'animorphs',
#  'no',
#  'greenwich village',
#  'yg entertainment',
#  'eenasul fateh',
#  '3677',
#  'annie morton',
#  'yes',
#  'kansas song we’re from kansas',
#  'david weissman',
#  '1999',
#  'yes',
#  '1986 to 2013',
#  'eastern college athletic conferencenorth',
#  'yes',
#  'sergio pérez',
#  'badly drawn boy',
#  'best goalkeeper',
#  '1838',
#  'yes',
#  'henry john kaiser',
#  'march 14 2000',
#  'thornhill ontario',
#  'charles nungesser',
#  'no',
#  'letters to cleo',
#  '2000',
#  'world war ii',
#  'no',
#  'upper manhattan',
#  'scotch collie',
#  '1962',
#  'ethiopian sovereignty',
#  'nelson aldrich rockefeller',
#  'yellowcraig',
#  'phil spector',
#  'world summit of nobel peace laureates',
#  'yes',
#  'english electric canberra',
#  '2009 big 12 conference football season',
#  '14',
#  'marion',
#  'drifting',
#  'jerry glanville',
#  '35124',
#  'yes',
#  'head coach',
#  '70',
#  'charmed',
#  'international boxing hall of fame',
#  'usher',
# ...

# %%
original_gold_answers=!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/logs/log_longformer_hotpotqa_reduced_train_answer_d7d5adc74a0d0b7ba99a6ee9ef19be0270b17c60_1gpu.txt" |  awk -F ':' '{sub("\t ", "", $NF); print $NF}'   )

# %%
original_gold_answers
# Out:
# ['yes',
#  'animorphs',
#  'no',
#  'greenwich village new york city',
#  'yg entertainment',
#  'eenasul fateh',
#  '3677 seated',
#  'terry richardson',
#  'yes',
#  'kansas song',
#  'david weissman',
#  '1999',
#  'no',
#  'from 1986 to 2013',
#  'north atlantic conference',
#  'yes',
#  'pedro rodríguez',
#  'badly drawn boy',
#  'worlds best goalkeeper',
#  '1838',
#  'yes',
#  'henry j kaiser',
#  '2000',
#  'fujioka gunma',
#  'charles eugène',
#  'no',
#  'letters to cleo',
#  '2000',
#  'world war ii',
#  'no',
#  'new york city',
#  'scotch collie',
#  '1962',
#  'sovereignty',
#  'nelson rockefeller',
#  'yellowcraig',
#  'phil spector',
#  'organizations could come together to address global issues',
#  'yes',
#  'english electric canberra',
#  '2009 big 12 conference',
#  '1462',
#  'marion south australia',
#  'drifting',
#  'keith bostic',
#  '35124',
#  'no',
#  'shortest player ever to play in national basketball association',
#  'more than 70 countries',
# ...

# %%
#original_strat=!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/logs/log_longformer_hotpotqa_reduced_train_answer_d7d5adc74a0d0b7ba99a6ee9ef19be0270b17c60_1gpu.txt" |  awk -F ':' '{sub("\t ", "", $NF); print $NF}'   )

# %% [markdown]
# ### Reduced Context Prediction

# %%
# commit 098828f51dfca8107b3564f462b41e90521ac90a add [SEP] where sentences removed in reduced context
reduced_qids =!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/logs/log_longformer_hotpotqa_reduced_train_answer_reduced_context_098828f51dfca8107b3564f462b41e90521ac90a_1gpu.txt" | awk -F "[:\t]" '{ sub("^[ ]+", "", $(NF-6));  print $(NF-6)}'   )

# %%
reduced_qids
# Out:
# ['5a8b57f25542995d1e6f1371',
#  '5a85ea095542994775f606a8',
#  '5adbf0a255429947ff17385a',
#  '5a8e3ea95542995a26add48d',
#  '5abd94525542992ac4f382d2',
#  '5a85b2d95542997b5ce40028',
#  '5a87ab905542996e4f3088c1',
#  '5a7bbb64554299042af8f7cc',
#  '5a8db19d5542994ba4e3dd00',
#  '5a7166395542994082a3e814',
#  '5a877e5d5542993e715abf7d',
#  '5ab3b0bf5542992ade7c6e39',
#  '5ab56e32554299637185c594',
#  '5ab6d09255429954757d337d',
#  '5ab3e45655429976abd1bcd4',
#  '5ab29c24554299449642c932',
#  '5ae7a8175542993210983ed8',
#  '5ae2070a5542994d89d5b313',
#  '5ae22b8d554299234fd0440f',
#  '5adf37a95542995ec70e8f97',
#  '5abd259d55429924427fcf1a',
#  '5a828c8355429966c78a6a50',
#  '5ac23ff0554299636651994d',
#  '5ae4a3265542995ad6573de5',
#  '5ae0361155429925eb1afc2c',
#  '5abc0a5d5542993f40c73c64',
#  '5a7cc50e554299452d57ba3e',
#  '5a8ef2a75542995a26add583',
#  '5a80721b554299485f5985ef',
#  '5ab51dae5542991779162d82',
#  '5a7571135542992d0ec05f98',
#  '5a7a0e1e5542990783324e1a',
# ...

# %%
original_qids == reduced_qids
# Out:
# True

# %%
reduced_gold_answers=!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/logs/log_longformer_hotpotqa_reduced_train_answer_reduced_context_098828f51dfca8107b3564f462b41e90521ac90a_1gpu.txt" |  awk -F ':' '{sub("\t ", "", $NF); print $NF}'   )

# %%
reduced_gold_answers
# Out:
# ['yes',
#  'animorphs',
#  'no',
#  'greenwich village new york city',
#  'yg entertainment',
#  'eenasul fateh',
#  '3677 seated',
#  'terry richardson',
#  'yes',
#  'kansas song',
#  'david weissman',
#  '1999',
#  'no',
#  'from 1986 to 2013',
#  'north atlantic conference',
#  'yes',
#  'pedro rodríguez',
#  'badly drawn boy',
#  'worlds best goalkeeper',
#  '1838',
#  'yes',
#  'henry j kaiser',
#  '2000',
#  'fujioka gunma',
#  'charles eugène',
#  'no',
#  'letters to cleo',
#  '2000',
#  'world war ii',
#  'no',
#  'new york city',
#  'scotch collie',
#  '1962',
#  'sovereignty',
#  'nelson rockefeller',
#  'yellowcraig',
#  'phil spector',
#  'organizations could come together to address global issues',
#  'yes',
#  'english electric canberra',
#  '2009 big 12 conference',
#  '1462',
#  'marion south australia',
#  'drifting',
#  'keith bostic',
#  '35124',
#  'no',
#  'shortest player ever to play in national basketball association',
#  'more than 70 countries',
# ...

# %%
reduced_pre_answers=!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/logs/log_longformer_hotpotqa_reduced_train_answer_reduced_context_098828f51dfca8107b3564f462b41e90521ac90a_1gpu.txt" |  awk -F "[:\t]" '{sub("^[ ]+", "", $(NF-3)); sub("[ ]+$", "", $(NF-3));  print $(NF-3)}'   )

# %%
reduced_pre_answers
# Out:
# ['yes',
#  'animorphs',
#  'no',
#  'greenwich village',
#  'yg entertainment',
#  'eenasul fateh',
#  '4000 capacity 3677',
#  'terry richardson',
#  'no',
#  'we’re from kansas',
#  'david weissman',
#  '1999',
#  'yes',
#  '1986 to 2013',
#  'north atlantic conference',
#  'no',
#  'sergio pérez',
#  'badly drawn boy',
#  'iffhs worlds best goalkeeper',
#  '1838',
#  'yes',
#  'kaiser shipbuilding company',
#  '2000',
#  'thornhill ontario',
#  'charles nungesser',
#  'no',
#  'screaming trees',
#  '2000',
#  'world war ii',
#  'yes',
#  'new york',
#  'scotch collie',
#  '1962',
#  'sovereignty and freedom from colonization',
#  'nelson aldrich rockefeller',
#  'yellowcraig',
#  'phil spector',
#  'world summit of nobel peace laureates',
#  'yes',
#  'english electric canberra',
#  '2009 big 12 conference football season',
#  '1462',
#  'marion',
#  'fly on wall',
#  'jerry glanville',
#  '35124',
#  'yes',
#  'muggsy bogues',
#  'more than 70',
#  'charmed',
# ...

# %%
original_gold_answers == reduced_gold_answers
# Out:
# True

# %% [markdown]
# ### Compare

# %%
import pandas as pd 
pd.set_option('display.max_columns', None)  
pd.set_option("display.max_colwidth", None)

# %%
df = pd.DataFrame(list(zip(original_qids, original_gold_answers, original_pre_answers, reduced_pre_answers)), columns=['qids','gold_answers', 'original_pre_answers', 'reduced_pre_answers'])

# %%
df.shape[0]
# Out:
# 5075

# %%
# predict wrong with original context 
df.loc[df['gold_answers'] != df['original_pre_answers']].shape[0]
# Out:
# 2033

# %%
# predict wrong with reduced context 
df.loc[df['gold_answers'] != df['reduced_pre_answers']].shape[0]
# Out:
# 2085

# %%
# predict different with original or reduced context 
df.loc[df['original_pre_answers'] != df['reduced_pre_answers']].shape[0]
# Out:
# 1609

# %%
# predict wrong with both context and reduced context 
df.loc[(df['gold_answers'] != df['original_pre_answers']) & (df['gold_answers'] != df['reduced_pre_answers']) ].shape[0]
# Out:
# 1534

# %%
# predict wrong with both context and reduced context, and predict different
df.loc[(df['gold_answers'] != df['original_pre_answers']) & (df['gold_answers'] != df['reduced_pre_answers']) & (df['original_pre_answers'] != df['reduced_pre_answers']) ].shape[0]
# Out:
# 559

# %%
# predict correct with original context, but wroong with reduced context 
df.loc[(df['gold_answers'] != df['reduced_pre_answers']) & (df['original_pre_answers'] == df['gold_answers'])]
# Out:
#                           qids         gold_answers original_pre_answers  \
# 8     5a8db19d5542994ba4e3dd00                  yes                  yes
# 15    5ab29c24554299449642c932                  yes                  yes
# 26    5a7cc50e554299452d57ba3e      letters to cleo      letters to cleo
# 29    5ab51dae5542991779162d82                   no                   no
# 43    5ae73acb5542991e8301cc07             drifting             drifting
# ...                        ...                  ...                  ...
# 5048  5a90bb4e55429916514e7536                 1927                 1927
# 5051  5ae1f2d4554299234fd04358  rio gavin ferdinand  rio gavin ferdinand
# 5052  5adc6f6255429947ff173961        morning glory        morning glory
# 5064  5ae6793e5542991bbc9760e2                 1864                 1864
# 5068  5addb1515542995b365fab60                 1891                 1891
#
#      reduced_pre_answers
# 8                     no
# 15                    no
# ...

# %%
df.loc[(df['gold_answers'] == df['reduced_pre_answers']) & (df['original_pre_answers'] != df['gold_answers'])].head(15)
# Out:
#                          qids                 gold_answers  \
# 7    5a7bbb64554299042af8f7cc             terry richardson
# 14   5ab3e45655429976abd1bcd4    north atlantic conference
# 22   5ac23ff0554299636651994d                         2000
# 41   5ab84bf555429916710eb01f                         1462
# 54   5ae7e1fc55429952e35ea9cc                       orange
# 59   5abdf12255429976d4830a2f                    bob seger
# 86   5a8d5fc6554299585d9e37c6        spiderwick chronicles
# 95   5ae73c065542991e8301cc18        marshall mathers lp 2
# 124  5a7b3f4d5542992d025e67bb                   pasek paul
# 129  5a74c85055429916b0164218               alistair grant
# 148  5a75f79555429976ec32bcca          1999 odisha cyclone
# 149  5adef80b5542993a75d263c4                      crackle
# 172  5ae4f2c75542993aec5ec0fb  logan international airport
# 177  5ae4d3c95542990ba0bbb165              istanbul turkey
# 179  5a7b46e55542995eb53be8e5                   ordos city
#
# ...

# %%
df.loc[(df['gold_answers'].str.isnumeric()==False) & (df['gold_answers'] != df['reduced_pre_answers']) & (df['original_pre_answers'] == df['gold_answers'])]
# Out:
#                           qids         gold_answers original_pre_answers  \
# 8     5a8db19d5542994ba4e3dd00                  yes                  yes
# 15    5ab29c24554299449642c932                  yes                  yes
# 26    5a7cc50e554299452d57ba3e      letters to cleo      letters to cleo
# 29    5ab51dae5542991779162d82                   no                   no
# 43    5ae73acb5542991e8301cc07             drifting             drifting
# ...                        ...                  ...                  ...
# 5013  5ae75c395542991bbc9761f7       julia mckenzie       julia mckenzie
# 5031  5a7ca98f55429935c91b5288            christian            christian
# 5044  5adf6a5c5542995ec70e8ff9   watertown new york   watertown new york
# 5051  5ae1f2d4554299234fd04358  rio gavin ferdinand  rio gavin ferdinand
# 5052  5adc6f6255429947ff173961        morning glory        morning glory
#
#      reduced_pre_answers
# 8                     no
# 15                    no
# ...

# %%
df.loc[((df['gold_answers']=='yes') |(df['gold_answers']=='no') )& (df['gold_answers'] != df['reduced_pre_answers']) & (df['original_pre_answers'] == df['gold_answers'])]

#df.loc[((df['gold_answers']=='yes') |(df['gold_answers']=='no') )& (df['gold_answers'] != df['reduced_pre_answers']) & (df['original_pre_answers'] == df['gold_answers'])].shape[0]
# Out:
#                           qids gold_answers original_pre_answers  \
# 8     5a8db19d5542994ba4e3dd00          yes                  yes
# 15    5ab29c24554299449642c932          yes                  yes
# 29    5ab51dae5542991779162d82           no                   no
# 240   5ae25ed15542992decbdccd2           no                   no
# 368   5adeb95d5542992fa25da827          yes                  yes
# 384   5ac1a04e5542991316484b63           no                   no
# 580   5a8cec13554299441c6b9f7d          yes                  yes
# 655   5abeb0da5542997ec76fd34b          yes                  yes
# 662   5ab344fc55429969a97a811e           no                   no
# 709   5a8aee2c55429970aeb70338           no                   no
# 971   5a7e1cad55429965cec5ea75          yes                  yes
# 1298  5ab5de535542992aa134a3b6          yes                  yes
# 1505  5a7f010955429934daa2fc8b          yes                  yes
# ...

# %% [markdown]
# ### Context and Reduced context

# %%
with open('/xdisk/msurdeanu/fanluo/hotpotQA/Data/reduced_questions/context/hotpot_reduced_dev_distractor.json', "r", encoding = 'utf-8') as handle:
    data = json.load(handle)
    dev_df = pd.json_normalize(data)

# %%
dev_df
# Out:
#                                                                                                                       supporting_facts  \
# 0                                                                                                [[Scott Derrickson, 0], [Ed Wood, 0]]
# 1     [[The Hork-Bajir Chronicles, 0], [The Hork-Bajir Chronicles, 1], [The Hork-Bajir Chronicles, 2], [Animorphs, 0], [Animorphs, 1]]
# 2                                                                                       [[Laleli Mosque, 0], [Esma Sultan Mansion, 0]]
# 3                                                                                   [[Big Stone Gap (film), 0], [Adriana Trigiani, 0]]
# 4                                                                                                  [[2014 S/S, 0], [Winner (band), 0]]
# ...                                                                                                                                ...
# ...

# %%
with open('/xdisk/msurdeanu/fanluo/hotpotQA/Data/reduced_questions/reduced_context/hotpot_reduced_dev_distractor_reduced_context_detail.json', "r", encoding = 'utf-8') as handle:
    data = json.load(handle)
    dev_reduced_context_df = pd.json_normalize(data)

# %%
dev_reduced_context_df
# Out:
#                                                                       supporting_facts  \
# 0                                                              [[Scott Derrickson, 0]]
# 1     [[The Hork-Bajir Chronicles, 0], [The Hork-Bajir Chronicles, 1], [Animorphs, 0]]
# 2                                                                 [[Laleli Mosque, 0]]
# 3                                                              [[Adriana Trigiani, 0]]
# 4                                                  [[2014 S/S, 0], [Winner (band), 0]]
# ...                                                                                ...
# 5070                                                           [[York, 0], [Copsi, 3]]
# 5071                                            [[Coke Kahani, 0], [Yasir Hussain, 0]]
# 5072                                            [[Canfield's Diet Chocolate Fudge, 0]]
# 5073                              [[Billy (dog), 0], [Bosnian Coarse-haired Hound, 0]]
# ...

# %%
context_df=dev_df.join(dev_reduced_context_df, rsuffix='_reduced_context').join(df)

# %%
import string 
from pandas.core.common import flatten
def _normalize_text(s):
    def remove_articles(text):
        return re.sub(r'\b(a|an|the)\b', ' ', text)

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))

import re
import string
# def findWholeWord(w):
#     return re.compile(r'\b({0})\b'.format(re.escape(w.strip(string.punctuation))), flags=re.IGNORECASE).search
#     # strip(string.punctuation) to remove heading and ending punctuations in the answer, otherwise can not found correctly if heading or ending punctuations appears
    
def findWord(w, context):
    if(w == ''):
        return False
    if(len(list(re.finditer(str(w), str(context), re.IGNORECASE))) > 0):
        return True
    else:
        return False

# %%
context_df['context'] =  context_df['context'].map(lambda x: [( [_normalize_text(p[0])] + [[_normalize_text(s) for s in p[1]]]) for p in x])
context_df['context_flattened'] = context_df['context'].map(lambda x: list(flatten(x)))
context_df['context_joint'] = context_df['context_flattened'].map(lambda x: " ".join(x) )

# %%
context_df['reduced_context'] = context_df['context_reduced_context'].map(lambda x: [( [_normalize_text(p[0])] + [[_normalize_text(s) for s in p[1]]]) for p in x]) 
context_df['reduced_context_flattened'] = context_df['reduced_context'].map(lambda x: list(flatten(x)))
context_df['reduced_context_joint'] = context_df['reduced_context_flattened'].map(lambda x: " ".join(x) )

# %%
context_df=context_df.loc[:, ['_id', 'question', 'gold_answers', 'original_pre_answers','reduced_pre_answers', 'context', 'reduced_context', 'context_joint', 'reduced_context_joint', 'supporting_facts', 'supporting_facts_reduced_context', 'question_phrases', 'paras_phrases', 'common_phrases', 'path_phrases', 'extended_phrases', 'kept_para_sent', 'sp_in_reduced_context_ratio']]

# %%
context_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5075 entries, 0 to 5074
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   _id                               5075 non-null   object
#  1   question                          5075 non-null   object
#  2   gold_answers                      5075 non-null   object
#  3   original_pre_answers              5075 non-null   object
#  4   reduced_pre_answers               5075 non-null   object
#  5   context                           5075 non-null   object
#  6   reduced_context                   5075 non-null   object
#  7   context_joint                     5075 non-null   object
#  8   reduced_context_joint             5075 non-null   object
#  9   supporting_facts                  5075 non-null   object
#  10  supporting_facts_reduced_context  5075 non-null   object
# ...

# %%
context_df['normalized_answer_in_reduced_context'] = context_df.apply(lambda row:  findWord(_normalize_text(row['gold_answers']), _normalize_text(row['reduced_context_joint'])) == True , axis = 1)

# %%
context_df.loc[context_df['normalized_answer_in_reduced_context'] == 'False']
# Out:
# Empty DataFrame
# Columns: [_id, question, gold_answers, original_pre_answers, reduced_pre_answers, context, reduced_context, context_joint, reduced_context_joint, supporting_facts, supporting_facts_reduced_context, question_phrases, paras_phrases, common_phrases, path_phrases, extended_phrases, kept_para_sent, sp_in_reduced_context_ratio, normalized_answer_in_reduced_context]
# Index: []

# %% [markdown]
# ### Samples

# %%
# ### run graph_hotpotqa to enable calling reduce_context_with_phares_graph() to check the details of question_phrases, common_phrases, etc that are used to construct reduced_context

# #### IMPORTANT: need to maunally change kernel to 'spacy' first

# import sys
# sys.path.insert(-1, '/xdisk/msurdeanu/fanluo/miniconda3/lib/python3.8/site-packages')      #for module named 'nbformat'
# %run /home/u32/fanluo/Jupyter/experiments/transformers/graph_hotpotqa.ipynb

# %% [markdown]
# #### gold_answers  !=  reduced_pre_answers &  original_pre_answers  == gold_answers

# %% [markdown]
# ##### Sample1

# %%
context_df.loc[context_df['_id'] == '5ae73acb5542991e8301cc07']
# Out:
#                          _id  \
# 43  5ae73acb5542991e8301cc07
#
#                                                   question gold_answers  \
# 43  D1NZ is a series based on what oversteering technique?     drifting
#
#    original_pre_answers reduced_pre_answers  \
# 43             drifting         fly on wall
#
# ...

# %%
context_df.loc[context_df['_id'] == '5ae73acb5542991e8301cc07']['context'].values.tolist()
# Out:
# [[['raimund harmstorf',
#    ['raimund harmstorf 7 october 1939 in hamburg – 3 may 1998 in marktoberdorf was german actor',
#     'he became famous as protagonist of german tv mini series based on jack londons seawolf which was sold into many countries and starred later on successfully in another german tv series based on jules vernes michael strogoff']],
#   ['rising star france',
#    ['rising star is french musical television competition series based on rising star contest series based on israeli programme hakokhav haba',
#     'tv viewers become instant ultimate juries with expert panelists given only nominal percentage weight in voting',
#     'french rights were bought by specialized musicoriented station m6']],
#   ['iron man tv series',
#    ['iron man also known as iron man animated series is american animated television series based on marvel comics superhero iron man',
# ...

# %%
context_df.loc[context_df['_id'] == '5ae73acb5542991e8301cc07']['reduced_context'].values.tolist()
# Out:
# [[['iron man tv series',
#    ['series aired from 1994 to 1996 in syndication as part of marvel action hour which packaged iron man with another animated series based on marvel properties fantastic four with one halfhour episode from each series airing backtoback']],
#   ['list of office us tv series characters',
#    ['format of series is parody of fly on wall documentary technique that intersperses traditional situation comedy segments with mock interviews with shows characters provides audience access to ongoing interior monologues for all of main characters as well as occasional insights into other characters within show']],
#   ['night school web series',
#    ['series was written and created by cj daugherty and jack jewers']],
#   ['ripleys believe it or not tv series',
#    ['ripleys believe it or not',
#     'series was revived for abc in 1980s and was hosted primarily by jack palance',
#     'animated series based on ripleys franchise was also created']],
#   ['d1nz',
# ...

# %% [markdown]
# ##### Sample2

# %%
context_df.loc[context_df['_id'] == '5a90bb4e55429916514e7536']
# Out:
#                            _id  \
# 5048  5a90bb4e55429916514e7536
#
#                                                       question gold_answers  \
# 5048  When was the town Emma Gramatica given its current name?         1927
#
#      original_pre_answers reduced_pre_answers  \
# 5048                 1927                1942
#
# ...

# %%
context_df.loc[context_df['_id'] == '5a90bb4e55429916514e7536']['context'].values.tolist()
# Out:
# [[['fidenza',
#    ['fidenza is town and comune in province of parma emiliaromagna region italy',
#     'it has around 24000 inhabitants',
#     'town was renamed fidenza in 1927 recalling its roman name of fidentia before it was called borgo san donnino']],
#   ['my poor beloved mother',
#    ['my poor beloved mother spanishpobre mi madre querida is 1948 argentine drama film directed by homero manzi and ralph pappier and starring hugo del carril emma gramatica and aída luz',
#     'it was based on tango of same name by pascual contursi and josé betinotti']],
#   ['emma gramatica',
#    ['emma gramatica 25 october 1874 – 8 november 1965 was italian stage and film actress',
#     'she appeared in 29 films between 1919 and 1962',
#     'she was born in borgo san donnino today fidenza province of parma and died in ostia']],
#   ['giulio stival',
#    ['born in soave at young age stival started founded amateur dramatics in which he served both as director and as actor',
# ...

# %%
context_df.loc[context_df['_id'] == '5a90bb4e55429916514e7536']['reduced_context'].values.tolist()
# Out:
# [[['emma gramatica',
#    ['emma gramatica 25 october 1874 – 8 november 1965 was italian stage and film actress']],
#   ['giulio stival',
#    ['he made his professional debut in 1927 with stage company led by emma gramatica']],
#   ['peppino e la vecchia signora',
#    ['peppino e la vecchia signora also known as peppino e la nobile dama is 1954 italian comedy film directed by emma gramatica and piero ballerini']],
#   ['yes madam 1942 film',
#    ['yes madam italiansissignora is 1942 italian romance film directed by ferdinando maria poggioli and starring maría denis leonardo cortese and emma gramatica']],
#   ['irma gramatica',
#    ['her sisters anna capodaglio and emma gramatica were both actresses']]]]

# %% [markdown]
# ##### Sample3

# %%
context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358']
# Out:
#                            _id  \
# 5051  5ae1f2d4554299234fd04358
#
#                                                                                                     question  \
# 5051  Which English former professional footballer ho played as a centre-back, did  Chris Jones played with
#
#              gold_answers original_pre_answers reduced_pre_answers  \
# 5051  rio gavin ferdinand  rio gavin ferdinand       rio ferdinand
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358'].extended_phrases.values)
# Out:
# id:  ['5ae1f2d4554299234fd04358']
# question:  ['Which English former professional footballer ho played as a centre-back, did  Chris Jones played with ']
# gold_answer:  ['rio gavin ferdinand']
# original_pre_answer:  ['rio gavin ferdinand']
# reduced_pre_answer:  ['rio ferdinand']
# supporting_facts:  [list([['Chris Jones (footballer, born 1985)', 3], ['Rio Ferdinand', 0]])]
# supporting_facts_reduced_context:  [list([['Rio Ferdinand', 0]])]
# question_phrases:  [list([['english former professional footballer ho', 0.2635787687], ['chris jones', 0.1792023638], ['centreback', 0.1552149956], ['english', 0.1350423957]])]
# common_phrases:  [list(['english', 'chris jones', 'centreback'])]
# extended_phrases:  [list(['english', 'one', 'centreback', 'chris jones', 'english former professional footballer ho'])]

# %%
context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358']['context'].values.tolist()
# Out:
# [[['chris jones footballer born 1985',
#    ['chris jones is welsh semiprofessional footballer currently playing for cymru alliance side porthmadog',
#     'former professional with leeds united jones is currently in his fourth season with city',
#     'he made several appearances for leeds and was heavily involved with first team',
#     'chris was playing with likes of aaron lennon james milner rio ferdinand scott carson and alan smith during his spell with yorkshire outfit']],
#   ['david unsworth',
#    ['david gerald unsworth born 16 october 1973 is english former professional footballer and current manager of everton u23',
#     'as player unsworth played as centreback or leftback from 1991 until 2009']],
#   ['sean dyche',
#    ['sean mark dyche born 28 june 1971 is english former professional footballer who is currently manager of premier league side burnley position he has held since october 2012',
# ...

# %%
context_df.loc[context_df['_id'] == '5ae1f2d4554299234fd04358']['reduced_context'].values.tolist()
# Out:
# [[['chris jones footballer born 1985',
#    ['chris jones is welsh semiprofessional footballer currently playing for cymru alliance side porthmadog']],
#   ['david unsworth',
#    ['david gerald unsworth born 16 october 1973 is english former professional footballer and current manager of everton u23',
#     'as player unsworth played as centreback or leftback from 1991 until 2009']],
#   ['sean dyche',
#    ['sean mark dyche born 28 june 1971 is english former professional footballer who is currently manager of premier league side burnley position he has held since october 2012',
#     'during his playing career dyche played as centreback making his professional debut in 1990 and representing chesterfield whom he captained and scored for in fa cup semifinal bristol city luton town millwall watford and northampton town']],
#   ['steve james footballer',
#    ['steven robert steve james born 29 november 1949 is english former professional footballer who played at centreback']],
# ...

# %% [markdown]
# ##### Sample4

# %%
context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961']
# Out:
#                            _id  \
# 5052  5adc6f6255429947ff173961
#
#                                                                                     question  \
# 5052  Which plant genus is part of a family with a longer name, Morning glory or Rothmannia?
#
#        gold_answers original_pre_answers reduced_pre_answers  \
# 5052  morning glory        morning glory          rothmannia
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961'].extended_phrases.values)
# Out:
# id:  ['5adc6f6255429947ff173961']
# question:  ['Which plant genus is part of a family with a longer name, Morning glory or Rothmannia?']
# gold_answer:  ['morning glory']
# original_pre_answer:  ['morning glory']
# reduced_pre_answer:  ['rothmannia']
# supporting_facts:  [list([['Morning glory', 0], ['Rothmannia', 0]])]
# supporting_facts_reduced_context:  [list([['Rothmannia', 0]])]
# question_phrases:  [list([['long name morning glory', 0.2685238304], ['morning', 0.1699204253], ['part', 0.1653718455], ['family', 0.1539382847], ['rothmannia', 0.1263906998], ['plant genus', 0.1081966841]])]
# common_phrases:  [list(['morning', 'rothmannia'])]
# extended_phrases:  [list(['morning', 'ipomoea indica', 'rothmannia', 'family', 'long name morning glory', 'plant genus', 'part'])]

# %%
context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961']['context'].values.tolist()
# Out:
# [[['ipomoea indica',
#    ['ipomoea indica is species of flowering plant in family convolvulaceae known by several common names including blue morning glory oceanblue morning glory koali awa and blue dawn flower']],
#   ['ipomoea wrightii',
#    ['ipomea wrightii or wrights morning glory is species of morning glory',
#     'it is generally described as annual perennial vine or forb or herb',
#     'wrights morning glory is not native to united states and is considered as invasive species',
#     'it is found growing in southeastern part of united states']],
#   ['rothmannia',
#    ['rothmannia is genus of flowering plants in rubiaceae family',
#     'it was described in 1776 and is named for göran rothman 1739–1778 by thunberg – both were pupils of linnaeus',
#     'genus has wide distribution area and is found tropical and southern africa western indian ocean southern china to indochina and new guinea']],
#   ['ipomoea carnea',
# ...

# %%
context_df.loc[context_df['_id'] == '5adc6f6255429947ff173961']['reduced_context'].values.tolist()
# Out:
# [[['ipomoea indica',
#    ['ipomoea indica is species of flowering plant in family convolvulaceae known by several common names including blue morning glory oceanblue morning glory koali awa and blue dawn flower']],
#   ['ipomoea wrightii',
#    ['ipomea wrightii or wrights morning glory is species of morning glory']],
#   ['rothmannia',
#    ['rothmannia is genus of flowering plants in rubiaceae family']],
#   ['ipomoea carnea',
#    ['ipomoea carnea pink morning glory is species of morning glory']],
#   ['bonamia grandiflora',
#    ['bonamia grandiflora is rare species of flowering plant in morning glory family known by common names florida ladys nightcap florida bonamia and scrub morning glory']],
#   ['morning glory',
#    ['morning glory species belong to many genera some of which are']],
#   ['ipomoea sagittata',
#    ['ipomoea sagittata commonly called saltmarsh morning glory is species of flowering plant in morning glory family']],
#   ['ipomoea aquatica',
# ...

# %% [markdown]
# ##### Sample5

# %%
context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2']
# Out:
#                            _id  \
# 5064  5ae6793e5542991bbc9760e2
#
#                                                                                                                                                                                                                        question  \
# 5064  Until what year did the Chief of Justice of the Supreme Court that administered the presidential oath of office to Abraham Lincoln on his first inauguration as the 16th President of the United States hold that office?
#
#      gold_answers original_pre_answers reduced_pre_answers  \
# 5064         1864                 1864                1836
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2'].extended_phrases.values)
# Out:
# id:  ['5ae6793e5542991bbc9760e2']
# question:  ['Until what year did the Chief of Justice of the Supreme Court that administered the presidential oath of office to Abraham Lincoln on his first inauguration as the 16th President of the United States hold that office?']
# gold_answer:  ['1864']
# original_pre_answer:  ['1864']
# reduced_pre_answer:  ['1836']
# supporting_facts:  [list([['First inauguration of Abraham Lincoln', 0], ['First inauguration of Abraham Lincoln', 2], ['Roger B. Taney', 0]])]
# supporting_facts_reduced_context:  [list([['First inauguration of Abraham Lincoln', 0], ['First inauguration of Abraham Lincoln', 2], ['Roger B. Taney', 0]])]
# ...

# %%
context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2']['context'].values.tolist()
# Out:
# [[['inauguration of millard fillmore',
#    ['inauguration of millard fillmore as 13th president of united states was held on wednesday july 10 1850 at united states capitol in washington dc following death of president zachary taylor previous day',
#     'president zachary taylor died from severe intestinal illness which subsequently thrust millard fillmore into role of president',
#     'inauguration marked commencement of millard fillmores only term partial term of as president but he faced stressful climate',
#     'there was political hubbub surrounding compromise of 1850 decision which millard had days before taylors death confessed that he was against his party when it came to this issue',
#     'therefore as he entered into presidency he found himself appointing entirely new cabinet after taylors cabinet members resigned',
# ...

# %%
context_df.loc[context_df['_id'] == '5ae6793e5542991bbc9760e2']['reduced_context'].values.tolist()
# Out:
# [[['inauguration of millard fillmore',
#    ['inauguration of millard fillmore as 13th president of united states was held on wednesday july 10 1850 at united states capitol in washington dc following death of president zachary taylor previous day',
#     'during inauguration william cranch chief judge of us circuit court administered presidential oath of office to fillmore in chamber of house of representatives',
#     'millard fillmore was last thirdparty president to ever be sworn into office']],
#   ['first inauguration of abraham lincoln',
#    ['first inauguration of abraham lincoln as 16th president of united states was held on monday march 4 1861 on east portico of united states capitol in washington dc',
#     'inauguration marked commencement of first term of abraham lincoln as president and only term of hannibal hamlin as vice president',
#     'presidential oath of office was administered to lincoln by roger b taney chief justice of united states']],
# ...

# %% [markdown]
# ##### Sample6

# %%
context_df.loc[context_df['_id'] == '5addb1515542995b365fab60']
# Out:
#                            _id  \
# 5068  5addb1515542995b365fab60
#
#                                                                                     question  \
# 5068  In what year was the uprising that marred John P. Buchanan's term as governor ignited?
#
#      gold_answers original_pre_answers reduced_pre_answers  \
# 5068         1891                 1891                2011
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5addb1515542995b365fab60']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5addb1515542995b365fab60'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5addb1515542995b365fab60'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5addb1515542995b365fab60'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5addb1515542995b365fab60'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5addb1515542995b365fab60'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5addb1515542995b365fab60'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5addb1515542995b365fab60'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5addb1515542995b365fab60'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5addb1515542995b365fab60'].extended_phrases.values)
# Out:
# id:  ['5addb1515542995b365fab60']
# question:  ["In what year was the uprising that marred John P. Buchanan's term as governor ignited?"]
# gold_answer:  ['1891']
# original_pre_answer:  ['1891']
# reduced_pre_answer:  ['2011']
# supporting_facts:  [list([['John P. Buchanan', 2], ['Coal Creek War', 1]])]
# supporting_facts_reduced_context:  [list([['John P. Buchanan', 1]])]
# question_phrases:  [list([['john p buchanans', 0.2562443666], ['mar john p buchanans term', 0.2041162973], ['governor', 0.1458597102], ['year', 0.0543329699]])]
# common_phrases:  [list(['governor'])]
# extended_phrases:  [list(['john p buchanans', 'mar john p buchanans term', 'governor', 'year'])]

# %%
context_df.loc[context_df['_id'] == '5addb1515542995b365fab60']['context'].values.tolist()
# Out:
# [[['ss john p gaines',
#    ['ss john p gaines was liberty ship built during world war ii and named for politician john p gaines']],
#   ['north carolina gubernatorial election 1980',
#    ['north carolina gubernatorial election of 1980 was held on november 4 1980',
#     'despite north carolina going to ronald reagan in presidential race and us senate race being won by republican john p east popular democratic governor jim hunt won second term in office in landslide over i beverly lake',
#     'hunt thus became first governor of state elected to consecutive fouryear term following amendment to north carolina constitution allowing such run']],
#   ['cochran grange',
#    ['cochran grange also known as john p cochran house is historic home located in middletown new castle county delaware',
#     'it was built between 1842 and 1845 and consists of twostory five bay main block with twostory wing',
#     'design is influenced by greek revival italianate and georgian styles',
# ...

# %%
context_df.loc[context_df['_id'] == '5addb1515542995b365fab60']['reduced_context'].values.tolist()
# Out:
# [[['montgomery county sheriffs office pennsylvania',
#    ['on may 6 2011 eileen whalon behr who had been appointed sheriff by governor and confirmed by pennsylvania senate was sworn in to serve balance of john p durantes term']],
#   ['john p buchanan',
#    ['he served as governor of tennessee from 1891 to 1893 and was president of tennessee farmers alliance and laborers union in late 1880s',
#     'buchanans lone term as governor was largely marred by coal creek war armed uprising by coal miners aimed at ending states convict lease system']]]]

# %% [markdown]
# ##### Sample7

# %%
context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c']
# Out:
#                          _id  \
# 84  5a75f0ea5542994ccc91866c
#
#                                                question gold_answers  \
# 84  What major truck road is located in Backford Cross?          a41
#
#    original_pre_answers reduced_pre_answers  \
# 84                  a41               a5117
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c'].extended_phrases.values)
# Out:
# id:  ['5a75f0ea5542994ccc91866c']
# question:  ['What major truck road is located in Backford Cross?']
# gold_answer:  ['a41']
# original_pre_answer:  ['a41']
# reduced_pre_answer:  ['a5117']
# supporting_facts:  [list([['Backford Cross', 2], ['A41 road', 0]])]
# supporting_facts_reduced_context:  [list([['Backford Cross', 1]])]
# question_phrases:  [list([['major truck road', 0.2810282579], ['backford cross', 0.222998813]])]
# common_phrases:  [list(['backford cross'])]
# extended_phrases:  [list(['major truck road', 'backford cross'])]

# %%
context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c']['context'].values.tolist()
# Out:
# [[['pureland industrial complex',
#    ['pureland industrial complex is 3000 acre industrial park located in logan township in gloucester county new jersey united states',
#     'it borders delaware river and raccoon creek and is located 12 mi south of ports of camden and philadelphia',
#     'interstate 295 us route 322 and us route 130 run through it and connect it to major truck routes',
#     'sms rail lines connect to penns grove secondary and national rail network',
#     'it was opened in 1975 and is largest industrial park in state of new jersey and one of largest in world']],
#   ['backford cross',
#    ['backford cross is village on wirral peninsula cheshire england',
#     'it is suburb of town of ellesmere port and part of cheshire west and chester',
#     'backford cross is located around a41a5117 junction south of great sutton and about 15 mi north of village of backford near chester',
# ...

# %%
context_df.loc[context_df['_id'] == '5a75f0ea5542994ccc91866c']['reduced_context'].values.tolist()
# Out:
# [[['backford cross',
#    ['backford cross is village on wirral peninsula cheshire england',
#     'backford cross is located around a41a5117 junction south of great sutton and about 15 mi north of village of backford near chester',
#     'backford cross is largely made up of residential homes built from 1990 onwards and serves as commuter village to ellesmere port and chester although inhabitants show no allegiance to either locality']],
#   ['a5117 road',
#    ['east of junction road is single carriageway and crosses a41 by way of roundabout at backford cross']],
#   ['strawberry park cheshire',
#    ['they are located to south of hope farm and to west of backford cross']]]]

# %% [markdown]
# ##### Sample8

# %%
context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8']
# Out:
#                          _id  \
# 65  5aba749055429901930fa7d8
#
#                                                    question gold_answers  \
# 65  What occupation do Chris Menges and Aram Avakian share?     director
#
#    original_pre_answers       reduced_pre_answers  \
# 65             director  film editor and director
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8'].extended_phrases.values)
# Out:
# id:  ['5aba749055429901930fa7d8']
# question:  ['What occupation do Chris Menges and Aram Avakian share?']
# gold_answer:  ['director']
# original_pre_answer:  ['director']
# reduced_pre_answer:  ['film editor and director']
# supporting_facts:  [list([['Aram Avakian', 0], ['Chris Menges', 0]])]
# supporting_facts_reduced_context:  [list([['Aram Avakian', 0]])]
# question_phrases:  [list([['aram avakian share', 0.2828427125], ['chris menges', 0.2676340205], ['aram avakian', 0.2676340205], ['occupation', 0.0858720581]])]
# common_phrases:  [list(['aram avakian', 'chris menges'])]
# extended_phrases:  [list(['aram avakian', 'chris menges', 'aram avakian share', 'occupation'])]

# %%
context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8']['context'].values.tolist()
# Out:
# [[['linda mvusi',
#    ['linda mvusi c 1955 in bloemfontein is actress and architect',
#     'mvusi took award for best actress at 1988 cannes film festival for her role in film world apart which was directed by chris menges',
#     'mvusi was first south african to get best actress award at cannes',
#     'mvusi also shared in award for excellence for her architecture on apartheid museum']],
#   ['second best film',
#    ['second best is 1994 british film produced by sarah radclyffe and directed by chris menges',
#     'it closely follows 1991 novel of same name by david cook who also wrote screenplay']],
#   ['11 harrowhouse',
#    ['11 harrowhouse is 1974 british film directed by aram avakian',
#     'it was adapted by charles grodin based upon novel by gerald browne with screenplay by jeffrey bloom',
#     'it stars charles grodin candice bergen james mason trevor howard and john gielgud']],
#   ['end of road 1970 film',
# ...

# %%
context_df.loc[context_df['_id'] == '5aba749055429901930fa7d8']['reduced_context'].values.tolist()
# Out:
# [[['linda mvusi',
#    ['mvusi took award for best actress at 1988 cannes film festival for her role in film world apart which was directed by chris menges']],
#   ['second best film',
#    ['second best is 1994 british film produced by sarah radclyffe and directed by chris menges']],
#   ['11 harrowhouse',
#    ['11 harrowhouse is 1974 british film directed by aram avakian']],
#   ['end of road 1970 film',
#    ['end of road is 1970 film directed cowritten and edited by aram avakian and adapted from 1958 novel by john barth and stars stacy keach james earl jones and harris yulin']],
#   ['chris menges', []],
#   ['world apart film',
#    ['world apart is 1988 antiapartheid drama written by shawn slovo and directed by chris menges']],
#   ['cops and robbers 1973 film',
#    ['cops and robbers is 1973 crime comedy film directed by aram avakian with original screenplay by donald e westlake which westlake subsequently expanded into novel']],
#   ['aram avakian',
# ...

# %% [markdown]
# ##### Sample9

# %%
context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c']
# Out:
#                           _id  \
# 114  5a74ce9655429974ef308c6c
#
#                                                                          question  \
# 114  What retailer in ABQ Uptown is headquarted in Poole, Dorset, United Kingdom?
#
#     gold_answers original_pre_answers reduced_pre_answers  \
# 114     lush ltd             lush ltd        lush company
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c'].extended_phrases.values)
# Out:
# id:  ['5a74ce9655429974ef308c6c']
# question:  ['What retailer in ABQ Uptown is headquarted in Poole, Dorset, United Kingdom?']
# gold_answer:  ['lush ltd']
# original_pre_answer:  ['lush ltd']
# reduced_pre_answer:  ['lush company']
# supporting_facts:  [list([['ABQ Uptown', 2], ['Lush (company)', 0]])]
# supporting_facts_reduced_context:  [list([['Lush (company)', 0]])]
# question_phrases:  [list([['poole dorset united kingdom', 0.2673478601], ['poole dorset', 0.2332647995], ['abq uptown', 0.2149936238], ['united kingdom', 0.2051307364], ['abq', 0.1655021688], ['retailer', 0.0744133368]])]
# common_phrases:  [list(['poole dorset', 'abq uptown', 'united kingdom', 'poole dorset united kingdom'])]
# extended_phrases:  [list(['viscount wimborne', 'poole dorset', 'abq uptown', 'united kingdom', 'poole dorset united kingdom', 'retailer', 'abq'])]

# %%
context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c']['context'].values.tolist()
# Out:
# [[['viscount wimborne',
#    ['viscount wimborne of canford magna in county of dorset is title in peerage of united kingdom',
#     'it was created in 1918 for ivor guest 2nd baron wimborne',
#     'guest family descends from engineer and businessman john josiah guest',
#     'on 14 august 1838 he was created baronet of dowlais in county of glamorgan in baronetage of united kingdom',
#     'he was succeeded by his eldest son second baronet',
#     'in 1880 he was created baron wimborne of canford magna in county of dorset in peerage of united kingdom',
#     'on his death titles passed to his eldest son second baron',
#     'in 1910 four years before he succeeded his father he had been raised to peerage of united kingdom in his own right as baron ashby st ledgers of ashby st ledgers in county of northampton',
# ...

# %%
context_df.loc[context_df['_id'] == '5a74ce9655429974ef308c6c']['reduced_context'].values.tolist()
# Out:
# [[['viscount wimborne',
#    ['viscount wimborne of canford magna in county of dorset is title in peerage of united kingdom',
#     'on 14 august 1838 he was created baronet of dowlais in county of glamorgan in baronetage of united kingdom',
#     'in 1880 he was created baron wimborne of canford magna in county of dorset in peerage of united kingdom',
#     'in 1910 four years before he succeeded his father he had been raised to peerage of united kingdom in his own right as baron ashby st ledgers of ashby st ledgers in county of northampton',
#     'on his retirement as lordlieutenant of ireland in 1918 he was further honoured when he was made viscount wimborne of canford magna in county of dorset in peerage of united kingdom']],
#   ['poole methodist church',
#    ['extension to church was nominated for 2016 carbuncle cup for ugliest building in united kingdom completed in last 12 months']],
#   ['baron de mauley',
# ...

# %% [markdown]
# ##### Sample10

# %%
context_df.loc[context_df['_id'] == '5a906a685542990a9849362e']
# Out:
#                           _id  \
# 112  5a906a685542990a9849362e
#
#                                                                                            question  \
# 112  Where was the world cup hosted that Algeria qualified for the first time into the round of 16?
#
#     gold_answers original_pre_answers reduced_pre_answers  \
# 112       brazil               brazil       south america
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a906a685542990a9849362e']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].extended_phrases.values)
# Out:
# id:  ['5a906a685542990a9849362e']
# question:  ['Where was the world cup hosted that Algeria qualified for the first time into the round of 16?']
# gold_answer:  ['brazil']
# original_pre_answer:  ['brazil']
# reduced_pre_answer:  ['south america']
# supporting_facts:  [list([['Algeria at the FIFA World Cup', 3], ['2014 FIFA World Cup', 1]])]
# supporting_facts_reduced_context:  [list([['Algeria at the FIFA World Cup', 3]])]
# question_phrases:  [list([['first time', 0.2022946281], ['world cup', 0.1997831499], ['first', 0.1647266308], ['algeria', 0.1605952339], ['round', 0.1539246232], ['16', 0.1002322352]])]
# common_phrases:  [list(['16', 'first time', 'world cup', 'first', 'algeria', 'round'])]
# extended_phrases:  [list(['algeria', '16', 'first time', 'world cup', 'first', 'round'])]

# %%
print("paras_phrases: ", context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].paras_phrases.values)
# Out:
# paras_phrases:  [list([[[['2015 cricket world cup opening ceremony', 0.3307189139], ['world cup', 0.2765063411], ['2015', 0.1697624529]], [['2015 cricket world cup', 0.1909020735], ['cricket world cup', 0.1763773306], ['world cup', 0.1502972763], ['23 year', 0.1443375673], ['new zealand', 0.140115832], ['2015', 0.1228937345], ['place', 0.1218820128], ['opening ceremony', 0.1205451416], ['beginning', 0.1147407684], ['australia', 0.1060892377], ['eve', 0.0936540812]], [['north hagley park christchurch', 0.1970152441], ['same time', 0.1532279546], ['new zealand', 0.1506145558], ['two ceremony', 0.138369973], ['place', 0.1322833819], ['melbourne australia', 0.1294945228], ['one', 0.1174505884], ['two', 0.1065172549], ['melbourne', 0.0996849302]], [['opening ceremony', 0.2433178695], ['thousand', 0.1669303398], ['fan', 0.1669303398], ['location', 0.0685502973]], [['deadly 2011 christchurch earthquake', 0.2533888296], ['major sporting event', 0.2356271046], ['christchurch', 0.1959367335], 
# ...

# %%
context_df.loc[context_df['_id'] == '5a906a685542990a9849362e']['context'].values.tolist()
# Out:
# [[['2015 cricket world cup opening ceremony',
#    ['opening ceremonies of 2015 cricket world cup took place in new zealand and australia on eve of beginning of world cup hosted by them after 23 years',
#     'two ceremonies took place at same time one in north hagley park christchurch in new zealand while other in melbourne australia',
#     'thousands of fans turned up to watch opening ceremony in both locations',
#     'it was first major sporting event hosted by christchurch after deadly 2011 christchurch earthquake']],
#   ['orvar bergmark',
#    ['orvar bergmark 16 november 1930 – 10 may 2004 was swedish football defender and manager',
#     'he was second swedish national manager ever and managed to qualify swedish national football team for fifa world cup in mexico 1970 after having beaten france among others in qualifications',
#     '1970 world cup was first one in 12 years and it was also first time in 20 years that sweden had qualified for world cup',
# ...

# %%
context_df.loc[context_df['_id'] == '5a906a685542990a9849362e']['reduced_context'].values.tolist()
# Out:
# [[['2015 cricket world cup opening ceremony',
#    ['opening ceremonies of 2015 cricket world cup took place in new zealand and australia on eve of beginning of world cup hosted by them after 23 years',
#     'it was first major sporting event hosted by christchurch after deadly 2011 christchurch earthquake']],
#   ['orvar bergmark',
#    ['1970 world cup was first one in 12 years and it was also first time in 20 years that sweden had qualified for world cup',
#     'sweden did not qualify for world cups in 1954 1962 and 1966']],
#   ['2002 fifa world cup',
#    ['it was first world cup to be held in asia first to be held on continent other than europe or americas last world cup during which golden goal rule was in force and only world cup to be jointly hosted by more than one nation',
#     'china pr ecuador senegal and slovenia made their first appearances at finals with turkey making its first appearance since 1954']],
#   ['1991 rugby world cup',
# ...

# %% [markdown]
# ##### Sample11

# %%
context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60']
# Out:
#                          _id  \
# 64  5a7759fc5542993569682d60
#
#                                                               question  \
# 64  Where are Teide National Park and Garajonay National Park located?
#
#             gold_answers  original_pre_answers            reduced_pre_answers  \
# 64  canary islands spain  canary islands spain  tenerife canary islands spain
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60'].extended_phrases.values)
# Out:
# id:  ['5a7759fc5542993569682d60']
# question:  ['Where are Teide National Park and Garajonay National Park located?']
# gold_answer:  ['canary islands spain']
# original_pre_answer:  ['canary islands spain']
# reduced_pre_answer:  ['tenerife canary islands spain']
# supporting_facts:  [list([['Teide National Park', 0], ['Garajonay National Park', 0]])]
# supporting_facts_reduced_context:  [list([['Teide National Park', 0]])]
# question_phrases:  [list([['garajonay national park', 0.3299142517], ['teide national park', 0.3170779899], ['national park', 0.3087454589], ['garajonay', 0.1954356706]])]
# common_phrases:  [list(['garajonay', 'teide national park', 'garajonay national park', 'national park'])]
# extended_phrases:  [list(['garajonay', 'teide national park', 'garajonay national park', 'national park'])]

# %%
context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60']['context'].values.tolist()
# Out:
# [[['hermigua',
#    ['hermigua is town and municipality in northeastern part of la gomera in province of santa cruz de tenerife of canary islands spain',
#     'it is located 12 km northwest of islands capital san sebastián de la gomera',
#     'garajonay national park covers southern part of municipality']],
#   ['garajonay national park',
#    ['garajonay national park spanish parque nacional de garajonay is located in center and north of island of la gomera one of canary islands spain',
#     'it was declared national park in 1981 and world heritage site by unesco in 1986',
#     'it occupies 40 km 15 sq mi and it extends into each of six municipalities on island']],
#   ['teide national park',
#    ['teide national park spanish parque nacional del teide is national park located in tenerife canary islands spain']],
#   ['crater lake national park',
#    ['crater lake national park is united states national park located in southern oregon',
# ...

# %%
context_df.loc[context_df['_id'] == '5a7759fc5542993569682d60']['reduced_context'].values.tolist()
# Out:
# [[['hermigua',
#    ['garajonay national park covers southern part of municipality']],
#   ['garajonay national park',
#    ['it was declared national park in 1981 and world heritage site by unesco in 1986']],
#   ['teide national park',
#    ['teide national park spanish parque nacional del teide is national park located in tenerife canary islands spain']],
#   ['adenocarpus viscosus',
#    ['it can be found above 1800 m on two of islands la palma in caldera de tabouriente and tenerife where it is dominant shrub in teide national park and occurs in parts of corona forestal nature park and reserva especial de las palomas']],
#   ['training centre for release of atmaenergy',
#    ['this sect was originally splinter group of brahma kumaris and is known for police and media scare in which alleged attempt to commit ritual suicide took place in teide national park in tenerife']],
#   ['alpine national park',
# ...

# %% [markdown]
# ##### Sample12

# %%
context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5']
# Out:
#                          _id  \
# 81  5a7dcc775542990b8f503ab5
#
#                                                  question gold_answers  \
# 81  Which component of shellite has the formula (ON)CHOH?  picric acid
#
#    original_pre_answers      reduced_pre_answers  \
# 81          picric acid  picric acid picric acid
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5'].extended_phrases.values)
# Out:
# id:  ['5a7dcc775542990b8f503ab5']
# question:  ['Which component of shellite has the formula (ON)CHOH?']
# gold_answer:  ['picric acid']
# original_pre_answer:  ['picric acid']
# reduced_pre_answer:  ['picric acid picric acid']
# supporting_facts:  [list([['Shellite (explosive)', 0], ['Picric acid', 0], ['Picric acid', 4]])]
# supporting_facts_reduced_context:  [list([['Shellite (explosive)', 0], ['Picric acid', 0]])]
# question_phrases:  [list([['formula onchoh', 0.303682383], ['shellite', 0.2854763267], ['component', 0.0940108888]])]
# common_phrases:  [list(['formula onchoh', 'shellite'])]
# extended_phrases:  [list(['formula onchoh', 'shellite', 'picric acid', 'component'])]

# %%
context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5']['context'].values.tolist()
# Out:
# [[['isopropyl alcohol',
#    ['isopropyl alcohol iupac name propan2ol also called dimethyl carbinol or incorrectly isopropanol is compound with chemical formula cho or choh or chchohch sometimes represented as iproh',
#     'it is colorless flammable chemical compound with strong odor',
#     'as propyl group linked to hydroxyl group it is simplest example of secondary alcohol where alcohol carbon atom is attached to two other carbon atoms sometimes shown as chchoh',
#     'it is structural isomer of 1propanol',
#     'it has wide variety of industrial and household uses and is common ingredient in chemicals such as antiseptics disinfectants and detergents']],
#   ['index of alcoholrelated articles',
#    ['alcohol is any organic compound in which hydroxyl functional group oh is bound to carbon atom usually connected to other carbon or hydrogen atoms',
#     'important class are simple acyclic alcohols general formula for which is choh',
# ...

# %%
context_df.loc[context_df['_id'] == '5a7dcc775542990b8f503ab5']['reduced_context'].values.tolist()
# Out:
# [[['shellite explosive',
#    ['shellite known as tridite in us service is explosive mixture of picric acid and dinitrophenol or picric acid and hexanitrodiphenylamine in ratio of 7030']],
#   ['picric acid', ['picric acid is organic compound with formula onchoh']]]]

# %% [markdown]
# ##### Sample13

# %%
context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684']
# Out:
#                          _id  \
# 94  5a80071f5542992bc0c4a684
#
#                                                                                question  \
# 94  Alice David is the voice of Lara Croft in a video game developed by which company ?
#
#         gold_answers original_pre_answers reduced_pre_answers  \
# 94  crystal dynamics     crystal dynamics         core design
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].extended_phrases.values)
# Out:
# id:  ['5a80071f5542992bc0c4a684']
# question:  ['Alice David is the voice of Lara Croft in a video game developed by which company ?']
# gold_answer:  ['crystal dynamics']
# original_pre_answer:  ['crystal dynamics']
# reduced_pre_answer:  ['core design']
# supporting_facts:  [list([['Alice David', 1], ['Tomb Raider (2013 video game)', 0]])]
# supporting_facts_reduced_context:  [list([['Alice David', 1]])]
# question_phrases:  [list([['video game', 0.2194265874], ['lara croft', 0.2169826102], ['voice', 0.1821481704], ['alice david', 0.1776531906], ['company', 0.0567396294]])]
# common_phrases:  [list(['company', 'voice', 'alice david', 'video game', 'lara croft'])]
# extended_phrases:  [list(['company', 'voice', 'alice david', 'video game', 'e3 2014', 'lara croft'])]

# %%
context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684']['context'].values.tolist()
# Out:
# [[['list of tomb raider media',
#    ['tomb raider is media franchise consisting of actionadventure games comic books novels theme park rides and movies centring on adventures of female fictional british archaeologist lara croft',
#     'since release of original tomb raider in 1996 series developed into lucrative franchise of related media and lara went on to become major icon of video game industry',
#     'guinness book of world records has recognised lara croft as most successful human videogame heroine in 2006',
#     'six games in series were developed by core design and latest four by crystal dynamics',
#     'all games were first published by eidos interactive now eidos officially became part of square enix on 22 april 2009 meaning square enix owns rights to tomb raider trademark and characters of franchise',
#     'to date two movies and have been produced starring american actress angelina jolie as lara croft',
#     'reboot was announced in 2016']],
#   ['tomb raider',
# ...

# %%
context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684']['reduced_context'].values.tolist()
# Out:
# [[['list of tomb raider media',
#    ['tomb raider is media franchise consisting of actionadventure games comic books novels theme park rides and movies centring on adventures of female fictional british archaeologist lara croft',
#     'guinness book of world records has recognised lara croft as most successful human videogame heroine in 2006',
#     'to date two movies and have been produced starring american actress angelina jolie as lara croft']],
#   ['tomb raider',
#    ['tomb raider also known as lara croft tomb raider between 2001 and 2007 is media franchise that originated with actionadventure video game series created by british gaming company core design',
#     'formerly owned by eidos interactive then by square enix after their acquisition of eidos in 2009 franchise focuses on fictional english archaeologist lara croft who travels around world searching for lost artifacts and infiltrating dangerous tombs and ruins']],
#   ['lara croft go',
# ...

# %% [markdown]
# ##### Sample14

# %%
context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053']
# Out:
#                          _id  \
# 99  5ac2d1d755429921a00ab053
#
#                                                             question  \
# 99  Who had the best singles ranking, Roberta Vinci or Jorge Lozano?
#
#      gold_answers original_pre_answers reduced_pre_answers  \
# 99  roberta vinci        roberta vinci        jorge lozano
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].extended_phrases.values)
# Out:
# id:  ['5ac2d1d755429921a00ab053']
# question:  ['Who had the best singles ranking, Roberta Vinci or Jorge Lozano?']
# gold_answer:  ['roberta vinci']
# original_pre_answer:  ['roberta vinci']
# reduced_pre_answer:  ['jorge lozano']
# supporting_facts:  [list([['Roberta Vinci', 0], ['Roberta Vinci', 1], ['Jorge Lozano', 2]])]
# supporting_facts_reduced_context:  [list([['Roberta Vinci', 0]])]
# question_phrases:  [list([['roberta vinci', 0.2646203648], ['good single', 0.2234236929], ['jorge lozano', 0.1986990941]])]
# common_phrases:  [list(['jorge lozano', 'roberta vinci'])]
# extended_phrases:  [list(['jorge lozano', 'roberta vinci', 'good single'])]

# %%
context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053']['context'].values.tolist()
# Out:
# [[['2015 rogers cup – womens doubles',
#    ['sara errani and roberta vinci were defending champions but chose not participate together',
#     'errani played alongside flavia pennetta but lost in quarterfinals to bethanie matteksands and lucie šafářová',
#     'vinci teamed up with jelena janković but lost in first round to garbiñe muguruza and carla suárez navarro',
#     'br']],
#   ['morbo band',
#    ['morbo was mexican electronicasynthpopambientalternative rock group formed by juan carlos lozano',
#     'lozano was one of four founding members of moenia which originally included juan carlos lozano as lead vocalist on 1997s debut album moenia and its 1998 companion remix album moenia mixes',
# ...

# %%
context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053']['reduced_context'].values.tolist()
# Out:
# [[['2015 rogers cup – womens doubles',
#    ['sara errani and roberta vinci were defending champions but chose not participate together']],
#   ['roberta vinci',
#    ['roberta vinci born 18 february 1983 is italian tennis player']],
#   ['2011 barcelona ladies open – doubles',
#    ['sara errani and roberta vinci were defending champions but roberta vinci chose not to continue her performance before quarterfinals']],
#   ['1994 athens international – doubles',
#    ['horacio de la peña and jorge lozano were defending champions but did not participate this year']],
#   ['flavia pennetta',
#    ['she became grand slam singles champion winning 2015 us open by defeating her childhood friend roberta vinci in first allitalian grand slam final']],
#   ['marta domachowska',
#    ['she reached 2008 australian open fourth round in singles and won 2006 canberra international in doubles with roberta vinci']],
#   ['jorge lozano',
# ...

# %% [markdown]
# ##### Sample15

# %%
context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3']
# Out:
#                           _id  \
# 102  5a738d27554299623ed4abf3
#
#                                               question gold_answers  \
# 102  Who was born first, Erika Jayne or Marco Da Silva  erika jayne
#
#     original_pre_answers reduced_pre_answers  \
# 102          erika jayne       erika girardi
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3'].extended_phrases.values)
# Out:
# id:  ['5a738d27554299623ed4abf3']
# question:  ['Who was born first, Erika Jayne or Marco Da Silva']
# gold_answer:  ['erika jayne']
# original_pre_answer:  ['erika jayne']
# reduced_pre_answer:  ['erika girardi']
# supporting_facts:  [list([['Marco Da Silva (dancer)', 0], ['Erika Jayne', 0]])]
# supporting_facts_reduced_context:  [list([['Erika Jayne', 0], ['Marco Da Silva (dancer)', 0]])]
# question_phrases:  [list([['first erika jayne', 0.2785289269], ['erika jayne', 0.25980909], ['marco da silva', 0.249887825]])]
# common_phrases:  [list(['marco da silva', 'erika jayne'])]
# extended_phrases:  [list(['marco da silva dancer', 'marco da silva', 'erika jayne', 'first erika jayne'])]

# %%
context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3']['context'].values.tolist()
# Out:
# [[['erika jayne',
#    ['erika girardi born 10 july 1971 known professionally as erika jayne is american singer actress and television personality',
#     'raised in atlanta girardi came to prominence with release of her debut single roller coaster which topped us billboard dance club songs chart in 2007 it was included on her debut studio album pretty mess in 2009',
#     'jayne has attained nine numberone songs on dance club songs chart as of 2016 most recently how many fucks',
#     'she is ranked 42 on billboards 100 greatest of all time dance club artists']],
#   ['emílio da silva',
#    ['emilio ribeiro neves da silva known simply as emílio da silva born 5 april 1982 in dili timor timur indonesia is footballer from east timor who has represented ad esperança since 2004',
#     'prior to this da silva played for fc zebra for two years having spent entirety of his youth career 2000–2002 there also']],
#   ['marquinhos footballer born june 1989',
# ...

# %%
context_df.loc[context_df['_id'] == '5a738d27554299623ed4abf3']['reduced_context'].values.tolist()
# Out:
# [[['erika jayne',
#    ['erika girardi born 10 july 1971 known professionally as erika jayne is american singer actress and television personality']],
#   ['marco da silva dancer',
#    ['marco da silva born may 30th 1977 is portuguese dancer and choreographer']],
#   ['marco da silva french footballer',
#    ['marco da silva born 10 april 1992 is french football player who plays for french club valenciennes in ligue 1']]]]

# %% [markdown]
# ##### Sample16

# %%
context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4']
# Out:
#                           _id  \
# 104  5a8704f8554299211dda2ba4
#
#                                                                                                       question  \
# 104  What is the name of the Isles who were led by Aonghus Mór and covered a total land area of over 8300 km2?
#
#          gold_answers original_pre_answers reduced_pre_answers  \
# 104  kingdom of isles     kingdom of isles       lord of islay
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4'].extended_phrases.values)
# Out:
# id:  ['5a8704f8554299211dda2ba4']
# question:  ['What is the name of the Isles who were led by Aonghus Mór and covered a total land area of over 8300 km2?']
# gold_answer:  ['kingdom of isles']
# original_pre_answer:  ['kingdom of isles']
# reduced_pre_answer:  ['lord of islay']
# supporting_facts:  [list([['Aonghus Mór', 0], ['Kingdom of the Isles', 0], ['Kingdom of the Isles', 6]])]
# supporting_facts_reduced_context:  [list([['Kingdom of the Isles', 0], ['Kingdom of the Isles', 3]])]
# question_phrases:  [list([['total land area', 0.2229481807], ['aonghus mór', 0.1937910127], ['isle', 0.1356455721], ['name', 0.1041630668], ['8300 km2', 0.0904824232]])]
# common_phrases:  [list(['isle', 'total land area', '8300 km2', 'aonghus mór'])]
# extended_phrases:  [list(['isle', 'total land area', 'distant norwegian crown', 'aonghus mór', 'island', '8300 km2', 'name'])]

# %%
context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4']['context'].values.tolist()
# Out:
# [[['lord of islay',
#    ['lord of islay was thirteenth and fourteenthcentury title borne by chiefs of clann domhnaill before they assumed title lord of isles in late fourteenth century',
#     'first person regarded to have styled themself lord of islay is aonghus mór son of eponymous ancestor of clan domhnall mac raghnaill',
#     'designation of islay was frequently used by these lords and later members of clan']],
#   ['aonghus mór',
#    ['aonghus mór mac domhnaill died c1293 was leading figure in thirteenthcentury kingdoms of isles and scotland',
#     'he was son of domhnall mac raghnaill eponym of clann domhnaill branch of clann somhairle',
#     'aonghus mór appears to have succeeded his father in mid part of thirteenth century',
#     'at time rulers of isles were fiercely independent of scottish crown and owed nominal allegiance to distant norwegian crown',
# ...

# %%
context_df.loc[context_df['_id'] == '5a8704f8554299211dda2ba4']['reduced_context'].values.tolist()
# Out:
# [[['lord of islay',
#    ['first person regarded to have styled themself lord of islay is aonghus mór son of eponymous ancestor of clan domhnall mac raghnaill']],
#   ['aonghus mór',
#    ['aonghus mór appears to have succeeded his father in mid part of thirteenth century',
#     'at time rulers of isles were fiercely independent of scottish crown and owed nominal allegiance to distant norwegian crown']],
#   ['protected areas of himachal pradesh',
#    ['forests in himachal pradesh currently cover area of nearly 37691 sqkm which is about 383 of total land area of state',
#     'state government aims to increase forest cover to 50 of total land area']],
#   ['ashanti region',
#    ['ashanti region is located in south ghana and is third largest of 10 administrative regions occupying total land surface of 24389 km2 or 102 per cent of total land area of ghana']],
#   ['list of islands of tasmania',
# ...

# %% [markdown]
# #### gold_answers  !=  reduced_pre_answers &  original_pre_answers  != gold_answers

# %% [markdown]
# ##### Sample17

# %%
context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d']
# Out:
#                         _id  \
# 3  5a8e3ea95542995a26add48d
#
#                                                                               question  \
# 3  The director of the romantic comedy "Big Stone Gap" is based in what New York city?
#
#                       gold_answers original_pre_answers reduced_pre_answers  \
# 3  greenwich village new york city    greenwich village   greenwich village
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].extended_phrases.values)
# Out:
# id:  ['5a8e3ea95542995a26add48d']
# question:  ['The director of the romantic comedy "Big Stone Gap" is based in what New York city?']
# gold_answer:  ['greenwich village new york city']
# original_pre_answer:  ['greenwich village']
# reduced_pre_answer:  ['greenwich village']
# supporting_facts:  [list([['Big Stone Gap (film)', 0], ['Adriana Trigiani', 0]])]
# supporting_facts_reduced_context:  [list([['Adriana Trigiani', 0]])]
# question_phrases:  [list([['romantic comedy big stone gap', 0.266965619], ['new york city', 0.2067222536], ['director', 0.1155316081]])]
# common_phrases:  [list(['new york city'])]
# extended_phrases:  [list(['romantic comedy big stone gap', 'new york city', 'director'])]

# %%
context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d']['context'].values.tolist()
# Out:
# [[['just another romantic wrestling comedy',
#    ['just another romantic wrestling comedy is 2006 film starring april hunter and joanie laurer',
#     'this romantic comedy film was premiered at new jersey and new york city on december 1 2006 and was released on dvd in united states and united kingdom on april 17 2007',
#     'after films dvd release just another romantic wrestling comedy won honorable mention award at new jersey international festival awards',
#     'release is being handled by victory multimedia']],
#   ['kingston morning',
#    ['kingston morning is dave eggars 4th solo release recorded in brooklyn new york kingston jamaica and big stone gap virginia and released by domo records',
#     'itsbynne reel was nominated at 53rd grammy awards for best instrumental arrangement']],
#   ['nola film',
#    ['nola is 2003 american romantic comedy film written and directed by alan hruska',
# ...

# %%
context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d']['reduced_context'].values.tolist()
# Out:
# [[['just another romantic wrestling comedy',
#    ['this romantic comedy film was premiered at new jersey and new york city on december 1 2006 and was released on dvd in united states and united kingdom on april 17 2007']],
#   ['nola film',
#    ['it depicts struggle of young woman trying to survive in new york city while looking for her birth father',
#     'it premiered in new york city on july 23 2004']],
#   ['adriana trigiani',
#    ['adriana trigiani is italian american bestselling author of sixteen books television writer film director and entrepreneur based in greenwich village new york city']],
#   ['great eastern conventions',
#    ['in new york city great eastern shows filled gap between mid1980s demise of annual comic art convention and creation conventions and establishment of promoter michael carbonaros annual big apple comic con in 1996',
#     'from 1993–1995 great eastern hosted two new york city shows annually at jacob k javits convention center']],
# ...

# %% [markdown]
# ##### Sample18

# %%
context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1']
# Out:
#                         _id  \
# 6  5a87ab905542996e4f3088c1
#
#                                                                                    question  \
# 6  The arena where the Lewiston Maineiacs played their home games can seat how many people?
#
#   gold_answers original_pre_answers reduced_pre_answers  \
# 6  3677 seated                 3677  4000 capacity 3677
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].extended_phrases.values)
# Out:
# id:  ['5a87ab905542996e4f3088c1']
# question:  ['The arena where the Lewiston Maineiacs played their home games can seat how many people?']
# gold_answer:  ['3677 seated']
# original_pre_answer:  ['3677']
# reduced_pre_answer:  ['4000 capacity 3677']
# supporting_facts:  [list([['Lewiston Maineiacs', 1], ['Androscoggin Bank Colisée', 0]])]
# supporting_facts_reduced_context:  [list([['Androscoggin Bank Colisée', 0], ['Lewiston Maineiacs', 1]])]
# question_phrases:  [list([['how many people', 0.1889591343], ['lewiston maineiacs', 0.179766227], ['arena', 0.1171501108], ['home game', 0.1078116566]])]
# common_phrases:  [list(['home game', 'lewiston maineiacs', 'arena'])]
# extended_phrases:  [list(['home game', 'lewiston maineiacs', 'richmond coliseum 1971–1972 richmond arena 1954–1971 benedictine high school gymnasium', 'androscoggin bank colisée', 'arena', 'how many people'])]

# %%
context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1']['context'].values.tolist()
# Out:
# [[['billings bulls',
#    ['billings bulls were junior ice hockey organization based in billings montana',
#     'they most recently played home games at 550seat centennial ice arena and due to arenas small size bulls frequently sold out games',
#     'they previously played their home games in metrapark which had max capacity of 9000 for hockey games',
#     'however negotiating dispute with arena officials and local county commissioners resulted in team losing its lease']],
#   ['robins center',
#    ['robins center is 7201seat multipurpose arena in richmond virginia',
#     'opened in 1972 arena is home to university of richmond spiders basketball',
#     'it hosted ecac south now known as colonial athletic association mens basketball tournament in 1983',
#     'it is named for e claiborne robins sr class of 1931 who along with his family have been leading benefactors for school',
# ...

# %%
context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1']['reduced_context'].values.tolist()
# Out:
# [[['billings bulls',
#    ['they most recently played home games at 550seat centennial ice arena and due to arenas small size bulls frequently sold out games',
#     'they previously played their home games in metrapark which had max capacity of 9000 for hockey games']],
#   ['robins center',
#    ['opened in 1972 arena is home to university of richmond spiders basketball',
#     'in intervening decades spiders played home games in numerous locations around richmond area including richmond coliseum 1971–1972 richmond arena 1954–1971 benedictine high school gymnasium 1951–1954 grays armory 1950–1951 and blues armory 1947–1950']],
#   ['2011–12 qmjhl season',
#    ['league lost one of his charter teams when lewiston maineiacs folded during after previous season qmjhl later announce expansion team to sherbrooke for 20122013 season']],
#   ['loan modification in united states',
# ...

# %% [markdown]
# ##### Sample19

# %%
context_df.loc[context_df['_id'] == '5a7166395542994082a3e814']
# Out:
#                         _id  \
# 9  5a7166395542994082a3e814
#
#                                                                                                                                                             question  \
# 9  What is the name of the fight song of the university whose main campus is in Lawrence, Kansas and whose branch campuses are in the Kansas City metropolitan area?
#
#   gold_answers           original_pre_answers reduced_pre_answers  \
# 9  kansas song  kansas song we’re from kansas   we’re from kansas
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].extended_phrases.values)
# Out:
# id:  ['5a7166395542994082a3e814']
# question:  ['What is the name of the fight song of the university whose main campus is in Lawrence, Kansas and whose branch campuses are in the Kansas City metropolitan area?']
# gold_answer:  ['kansas song']
# original_pre_answer:  ['kansas song we’re from kansas']
# reduced_pre_answer:  ['we’re from kansas']
# supporting_facts:  [list([['Kansas Song', 0], ['University of Kansas', 1], ['University of Kansas', 2]])]
# supporting_facts_reduced_context:  [list([['Kansas Song', 0], ['University of Kansas', 1], ['University of Kansas', 2]])]
# question_phrases:  [list([['kansas city metropolitan area', 0.2277596271], ['kansas city', 0.2035996587], ['lawrence kansas', 0.1932932619], ['fight song', 0.1782097201], ['university', 0.1533396213], ['name', 0.1159422513], ['main campus', 0.1090341684], ['branch campus', 0.1084453342]])]
# ...

# %%
context_df.loc[context_df['_id'] == '5a7166395542994082a3e814']['context'].values.tolist()
# Out:
# [[['north kansas city missouri',
#    ['north kansas city is city in clay county missouri united states that despite similarity in name to its larger counterpart kansas city is independent municipality part of kansas city metropolitan area',
#     'population was 4208 at 2010 census',
#     'originally northern suburb across missouri river from kansas city missouri it is now almost completely surrounded by kansas city which has annexed far to north of north kansas citys northern city limits',
#     'north kansas city also adjoins small municipality of avondale']],
#   ['university of missouri–kansas city',
#    ['university of missouri–kansas city umkc is public research university serving greater kansas city metropolitan area',
#     'located in kansas city missouri umkc is one of four system campuses that collectively constitute university of missouri',
# ...

# %%
context_df.loc[context_df['_id'] == '5a7166395542994082a3e814']['reduced_context'].values.tolist()
# Out:
# [[['north kansas city missouri',
#    ['north kansas city is city in clay county missouri united states that despite similarity in name to its larger counterpart kansas city is independent municipality part of kansas city metropolitan area',
#     'originally northern suburb across missouri river from kansas city missouri it is now almost completely surrounded by kansas city which has annexed far to north of north kansas citys northern city limits']],
#   ['university of missouri–kansas city',
#    ['university of missouri–kansas city umkc is public research university serving greater kansas city metropolitan area',
#     'located in kansas city missouri umkc is one of four system campuses that collectively constitute university of missouri',
# ...

# %% [markdown]
# ##### Sample20

# %%
context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d']
# Out:
#                          _id  \
# 13  5ab6d09255429954757d337d
#
#                                                                                              question  \
# 13  The football manager who recruited David Beckham managed Manchester United during what timeframe?
#
#          gold_answers original_pre_answers reduced_pre_answers  \
# 13  from 1986 to 2013         1986 to 2013        1986 to 2013
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].extended_phrases.values)
# Out:
# id:  ['5ab6d09255429954757d337d']
# question:  ['The football manager who recruited David Beckham managed Manchester United during what timeframe?']
# gold_answer:  ['from 1986 to 2013']
# original_pre_answer:  ['1986 to 2013']
# reduced_pre_answer:  ['1986 to 2013']
# supporting_facts:  [list([['1995–96 Manchester United F.C. season', 2], ['1995–96 Manchester United F.C. season', 3], ['Alex Ferguson', 0]])]
# supporting_facts_reduced_context:  [list([['Alex Ferguson', 0]])]
# question_phrases:  [list([['david beckham', 0.2279805132], ['manchester united', 0.211496625], ['football manager', 0.1732824433], ['manchester', 0.1590693629], ['timeframe', 0.0519410171]])]
# common_phrases:  [list(['david beckham', 'manchester united'])]
# extended_phrases:  [list(['david beckham', 'manchester united', 'football manager', 'timeframe', 'manchester'])]

# %%
context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d']['context'].values.tolist()
# Out:
# [[['joshua parlby',
#    ['joshua parlby born 1855 in longton staffordshire was english football manager who managed manchester city in 1890s']],
#   ['1996 fa charity shield',
#    ['1996 fa charity shield also known as littlewoods fa charity shield for sponsorship reasons was 74th fa charity shield annual football match played between winners of previous seasons premier league and fa cup competitions',
#     'match was played on 11 august 1996 at wembley stadium and contested by manchester united who had won double of premier league and fa cup in 1995–96 and newcastle united who had finished as runnersup in premier league',
#     'manchester united won match 4–0 with goals from eric cantona nicky butt david beckham and roy keane']],
#   ['sir matt busby sports complex',
#    ['sir matt busby sports complex is public leisure centre located in bellshill north lanarkshire scotland',
# ...

# %%
context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d']['reduced_context'].values.tolist()
# Out:
# [[['1996 fa charity shield',
#    ['match was played on 11 august 1996 at wembley stadium and contested by manchester united who had won double of premier league and fa cup in 1995–96 and newcastle united who had finished as runnersup in premier league',
#     'manchester united won match 4–0 with goals from eric cantona nicky butt david beckham and roy keane']],
#   ['sir matt busby sports complex',
#    ['it is named in honour of sir matt busby football manager who was born in bellshill in 1909 managed manchester united from 1945 to 1969 and died in 1994']],
#   ['ernest mangnall',
#    ['james ernest mangnall 4 january 1866 – 13 january 1932 was english football manager who started his career with burnley and managed manchester united between 1903–1912 and then went on to manage manchester city from 1912–1924 and is only man to date to have managed both clubs']],
#   ['david beckham academy',
# ...

# %% [markdown]
# ##### Sample21

# %%
context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8']
# Out:
#                          _id  \
# 16  5ae7a8175542993210983ed8
#
#                                                                                                             question  \
# 16  Which other Mexican Formula One race car driver has held the podium besides the Force India driver born in 1990?
#
#        gold_answers original_pre_answers reduced_pre_answers  \
# 16  pedro rodríguez         sergio pérez        sergio pérez
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].extended_phrases.values)
# Out:
# id:  ['5ae7a8175542993210983ed8']
# question:  ['Which other Mexican Formula One race car driver has held the podium besides the Force India driver born in 1990?']
# gold_answer:  ['pedro rodríguez']
# original_pre_answer:  ['sergio pérez']
# reduced_pre_answer:  ['sergio pérez']
# supporting_facts:  [list([['Formula One drivers from Mexico', 1], ['Formula One drivers from Mexico', 2], ['Sergio Pérez', 0]])]
# supporting_facts_reduced_context:  [list([['Sergio Pérez', 0], ['Formula One drivers from Mexico', 1], ['Formula One drivers from Mexico', 2]])]
# question_phrases:  [list([['one race car driver', 0.2353753935], ['force india driver', 0.2167847717], ['other mexican formula', 0.1804735381], ['one', 0.1459711451], ['india', 0.1234188453], ['mexican', 0.1228772199], ['podium', 0.1228765594], ['1990', 0.094228142]])]
# common_phrases:  [list(['mexican', 'one', 'podium', 'india'])]
# ...

# %%
context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8']['context'].values.tolist()
# Out:
# [[['2009 singapore grand prix',
#    ['2009 singapore grand prix formally 2009 formula 1 singtel singapore grand prix was formula one motor race held at marina bay street circuit in singapore on 27 september 2009',
#     '61lap race was fourteenth round of 2009 formula one season',
#     'it was second singapore grand prix to be part of formula one championship and tenth singapore grand prix overall',
#     'it was also second formula one race to be held at night',
#     'race was won by mclarenmercedes driver and reigning world champion lewis hamilton',
#     'toyotas timo glock finished second and 2008 race winner fernando alonso took third position making this only race of season with neither brawn nor red bull driver on podium',
#     'this was also last race of 2009 for glock as he was injured during qualifying for japanese grand prix and was replaced by test driver kamui kobayashi',
#     'heikki kovalainen scored his last ever world championship points at this race']],
# ...

# %%
context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8']['reduced_context'].values.tolist()
# Out:
# [[['2009 singapore grand prix',
#    ['2009 singapore grand prix formally 2009 formula 1 singtel singapore grand prix was formula one motor race held at marina bay street circuit in singapore on 27 september 2009',
#     '61lap race was fourteenth round of 2009 formula one season',
#     'it was second singapore grand prix to be part of formula one championship and tenth singapore grand prix overall',
#     'it was also second formula one race to be held at night',
#     'toyotas timo glock finished second and 2008 race winner fernando alonso took third position making this only race of season with neither brawn nor red bull driver on podium']],
#   ['catharina felser',
#    ['her performances there resulted in one race in german formula ford also during 2000']],
#   ['michael james lewis',
#    ['michael also officially tested formula one car for scuderia ferrari f1 in f60 chassis on november 15 2011 as result from his accomplishments in formula 3 italia']],
#   ['sergio pérez',
# ...

# %% [markdown]
# ##### Sample22

# %%
context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f']
# Out:
#                          _id  \
# 18  5ae22b8d554299234fd0440f
#
#                                                                       question  \
# 18  What was the father of Kasper Schmeichel voted to be by the IFFHS in 1992?
#
#               gold_answers original_pre_answers           reduced_pre_answers  \
# 18  worlds best goalkeeper      best goalkeeper  iffhs worlds best goalkeeper
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].extended_phrases.values)
# Out:
# id:  ['5ae22b8d554299234fd0440f']
# question:  ['What was the father of Kasper Schmeichel voted to be by the IFFHS in 1992?']
# gold_answer:  ['worlds best goalkeeper']
# original_pre_answer:  ['best goalkeeper']
# reduced_pre_answer:  ['iffhs worlds best goalkeeper']
# supporting_facts:  [list([['Kasper Schmeichel', 0], ['Kasper Schmeichel', 1], ['Peter Schmeichel', 0]])]
# supporting_facts_reduced_context:  [list([['Peter Schmeichel', 0]])]
# question_phrases:  [list([['kasper schmeichel', 0.2716671856], ['iffhs', 0.1924500897], ['1992', 0.1924500897], ['father', 0.1741807325]])]
# common_phrases:  [list(['1992', 'kasper schmeichel', 'father'])]
# extended_phrases:  [list(['gus williams musician', 'kasper schmeichel', 'country star warren h williams', '1992', 'father', 'iffhs worlds', 'iffhs'])]

# %%
context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f']['context'].values.tolist()
# Out:
# [[['gus williams musician',
#    ['kasper gus ntjalka williams oam known as gus williams 20 june 1937 – 13 september 2010 was country singer from hermannsburg in central australia',
#     'he was arrernte man who was born in alice springs',
#     'he was father of country star warren h williams']],
#   ['kasper hvidt',
#    ['kasper hvidt born 6 february 1976 in copenhagen is danish retired handball goalkeeper who lastly played for kif kolding and previous danish national team',
#     'he was selected as best keeper for 2008 european mens handball championship',
#     'hvidt was also voted as goalkeeper of year march 20 2009 second place was thierry omeyer from france']],
#   ['peter schmeichel',
#    ['peter bolesław schmeichel mbe born 18 november 1963 is danish former professional footballer who played as goalkeeper and was voted iffhs worlds best goalkeeper in 1992 and 1993',
# ...

# %%
context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f']['reduced_context'].values.tolist()
# Out:
# [[['gus williams musician',
#    ['he was father of country star warren h williams']],
#   ['peter schmeichel',
#    ['peter bolesław schmeichel mbe born 18 november 1963 is danish former professional footballer who played as goalkeeper and was voted iffhs worlds best goalkeeper in 1992 and 1993',
#     'he is best remembered for his most successful years at english club manchester united whom he captained to 1999 uefa champions league to complete treble and for winning uefa euro 1992 with denmark']],
#   ['sommeren 92',
#    ['film is based on 1992 uefa european football championship denmarks greatest ever football triumph',
#     'film examines often difficult relationship between teams coach richard møller nielsen and danish football association and leading players that nonetheless led to triumph in 1992']],
#   ['iffhs worlds best club coach', []],
#   ['iffhs worlds best goalkeeper',
# ...

# %% [markdown]
# #### gold_answers  ==  reduced_pre_answers &  original_pre_answers  != gold_answers

# %%
context_df.loc[ (context_df['gold_answers'] == context_df['reduced_pre_answers']) & (context_df['original_pre_answers'] != context_df['gold_answers']) &(context_df['supporting_facts_reduced_context'] == context_df['supporting_facts'])]['_id']
# Out:
# 179     5a7b46e55542995eb53be8e5
# 208     5add67915542992200553af8
# 246     5ae5e1345542996de7b71a50
# 273     5a8f69b55542997ba9cb324f
# 277     5adf4a275542993a75d26498
#                   ...
# 4800    5ab870ee5542990e739ec8f6
# 4867    5a793f505542994bb9456fd1
# 4905    5aba3e3355429901930fa78c
# 4953    5a7fc5875542992e7d278d67
# 5065    5a7e910a554299306751357f
# Name: _id, Length: 85, dtype: object

# %% [markdown]
# ##### Sample23

# %%
context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc']
# Out:
#                         _id                                         question  \
# 7  5a7bbb64554299042af8f7cc  Who is older, Annie Morton or Terry Richardson?
#
#        gold_answers original_pre_answers reduced_pre_answers  \
# 7  terry richardson         annie morton    terry richardson
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].extended_phrases.values)
# Out:
# id:  ['5a7bbb64554299042af8f7cc']
# question:  ['Who is older, Annie Morton or Terry Richardson?']
# gold_answer:  ['terry richardson']
# original_pre_answer:  ['annie morton']
# reduced_pre_answer:  ['terry richardson']
# supporting_facts:  [list([['Annie Morton', 0], ['Annie Morton', 2], ['Terry Richardson', 0]])]
# supporting_facts_reduced_context:  [list([['Annie Morton', 0], ['Annie Morton', 1]])]
# question_phrases:  [list([['old annie morton', 0.3196328348], ['annie morton', 0.3029458872], ['terry richardson', 0.2603367356]])]
# common_phrases:  [list(['annie morton', 'terry richardson'])]
# extended_phrases:  [list(['annie morton', 'terry richardson', 'old annie morton'])]

# %%
context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc']['context'].values.tolist()
# Out:
# [[['annie morton',
#    ['annie morton born october 8 1970 is american model born in pennsylvania',
#     'she has appeared on covers of british vogue id marie claire and other magazines',
#     'she has been photographed by helmut newton peter lindbergh annie leibovitz richard avedon juergen teller paul jasmin mary ellen mark and terry richardson and modeled for donna karan givenchy guerlain chanel harpers bazaar sports illustrated and victorias secret',
#     'long time vegetarian advocate for organic lifestyle choices and natural healthcare',
#     'she cofounded tsila organics green luxury company that creates and sells vegan organic perfume and skin care products']],
#   ['madonna book',
#    ['madonna is biography by english author andrew morton chronicling life of american recording artist madonna',
#     'book was released in november 2001 by st martins press in united states and in april 2002 by michael omara books in united kingdom',
# ...

# %%
context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc']['reduced_context'].values.tolist()
# Out:
# [[['annie morton',
#    ['annie morton born october 8 1970 is american model born in pennsylvania',
#     'she has been photographed by helmut newton peter lindbergh annie leibovitz richard avedon juergen teller paul jasmin mary ellen mark and terry richardson and modeled for donna karan givenchy guerlain chanel harpers bazaar sports illustrated and victorias secret']],
#   ['terry richardson', []],
#   ['lady gaga x terry richardson',
#    ['lady gaga x terry richardson is photobook by american singer lady gaga and american photographer terry richardson released on november 22 2011 by grand central publishing']],
#   ['amanda lepore',
#    ['lepore is also noted as regular subject in photographer david lachapelles work serving as his muse as well as many other photographers such as terry richardson and']],
#   ['piano girl',
# ...

# %% [markdown]
# ##### Sample24

# %%
context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4']
# Out:
#                          _id  \
# 14  5ab3e45655429976abd1bcd4
#
#                                                                                                                           question  \
# 14  The Vermont Catamounts men's soccer team currently competes in a conference that was formerly known as what from 1988 to 1996?
#
#                  gold_answers                      original_pre_answers  \
# 14  north atlantic conference  eastern college athletic conferencenorth
#
#           reduced_pre_answers  \
# 14  north atlantic conference
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].extended_phrases.values)
# Out:
# id:  ['5ab3e45655429976abd1bcd4']
# question:  ["The Vermont Catamounts men's soccer team currently competes in a conference that was formerly known as what from 1988 to 1996?"]
# gold_answer:  ['north atlantic conference']
# original_pre_answer:  ['eastern college athletic conferencenorth']
# reduced_pre_answer:  ['north atlantic conference']
# supporting_facts:  [list([["Vermont Catamounts men's soccer", 0], ["Vermont Catamounts men's soccer", 1], ['America East Conference', 1]])]
# supporting_facts_reduced_context:  [list([['America East Conference', 1], ["Vermont Catamounts men's soccer", 0]])]
# question_phrases:  [list([['vermont catamounts mens soccer team', 0.2358218859], ['conference', 0.1317574166], ['1988 1996', 0.1043281062]])]
# common_phrases:  [list(['conference', '1988 1996', 'vermont catamounts mens soccer team'])]
# extended_phrases:  [list(['conference', '1988 1996', 'ncaa', 'vermont catamounts mens soccer team'])]

# %%
context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4']['context'].values.tolist()
# Out:
# [[['2010–11 vermont catamounts mens basketball team',
#    ['2010–11 vermont catamounts mens basketball team represented university of vermont in 2010–11 ncaa division i mens basketball season',
#     'catamounts won their third consecutive america east conference regular season championship but lost in semifinals of conference tournament to stony brook',
#     'catamounts got invited to national invitation tournament but lost in first round to cleveland state 63–60']],
#   ['2012–13 vermont catamounts mens basketball team',
#    ['2012–13 vermont catamounts mens basketball team represented university of vermont during 2012–13 ncaa division i mens basketball season',
#     'catamounts led by second year head coach john becker played their home games at patrick gym and were members of america east conference',
#     'they finished season 21–12 11–5 in america east play to finish in tie for second place',
# ...

# %%
context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4']['reduced_context'].values.tolist()
# Out:
# [[['2010–11 vermont catamounts mens basketball team',
#    ['2010–11 vermont catamounts mens basketball team represented university of vermont in 2010–11 ncaa division i mens basketball season']],
#   ['2012–13 vermont catamounts mens basketball team',
#    ['2012–13 vermont catamounts mens basketball team represented university of vermont during 2012–13 ncaa division i mens basketball season']],
#   ['2013–14 vermont catamounts mens basketball team',
#    ['2013–14 vermont catamounts mens basketball team represented university of vermont during 2013–14 ncaa division i mens basketball season']],
#   ['america east conference',
#    ['america east conference is collegiate athletic conference affiliated with ncaa division i whose members are located mainly in northeastern united states',
#     'conference was known as eastern college athletic conferencenorth from 1979 to 1988 and north atlantic conference from 1988 to 1996']],
#   ['vermont catamounts mens soccer',
# ...

# %% [markdown]
# ##### Sample25

# %%
context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc']
# Out:
#                          _id  \
# 54  5ae7e1fc55429952e35ea9cc
#
#                                                                                                                       question  \
# 54  What color clothing do people of the Netherlands wear during Oranjegekte or to celebrate the national holiday Koningsdag?
#
#    gold_answers original_pre_answers reduced_pre_answers  \
# 54       orange          oranjegekte              orange
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].extended_phrases.values)
# Out:
# id:  ['5ae7e1fc55429952e35ea9cc']
# question:  ['What color clothing do people of the Netherlands wear during Oranjegekte or to celebrate the national holiday Koningsdag? ']
# gold_answer:  ['orange']
# original_pre_answer:  ['oranjegekte']
# reduced_pre_answer:  ['orange']
# supporting_facts:  [list([['Oranjegekte', 1], ['Koningsdag', 0]])]
# supporting_facts_reduced_context:  [list([['Koningsdag', 0]])]
# question_phrases:  [list([['national holiday koningsdag', 0.2139639175], ['people', 0.1746118615], ['color clothing', 0.1696979823], ['netherlands', 0.1494128133], ['oranjegekte', 0.1477666045]])]
# common_phrases:  [list(['oranjegekte', 'netherlands', 'people'])]
# extended_phrases:  [list(['oranjegekte', 'netherlands', 'most widely use instrument', 'koningsdag', 'people', 'jounen kwéyòl', 'national holiday koningsdag', 'color clothing'])]

# %%
context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc']['context'].values.tolist()
# Out:
# [[['queens day disambiguation',
#    ['queens day or koninginnedag is former name of national holiday in netherlands netherlands antilles and aruba from 1890 to 2013',
#     'it has since been renamed kings day or koningsdag to honor birthday of king willemalexander']],
#   ['childrens day japan',
#    ['childrens day こどもの日 kodomo no hi is japanese national holiday which takes place annually on may 5 fifth day of fifth month and is final celebration in golden week',
#     'it is day set aside to respect childrens personalities and to celebrate their happiness',
#     'it was designated national holiday by japanese government in 1948',
#     'it has been day of celebration in japan since ancient times']],
#   ['garifuna settlement day',
#    ['garifuna settlement day is public holiday in belize celebrated each year on november 19',
#     'holiday was created by belizean civil rights activist thomas vincent ramos in 1941',
# ...

# %%
context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc']['reduced_context'].values.tolist()
# Out:
# [[['queens day disambiguation',
#    ['queens day or koninginnedag is former name of national holiday in netherlands netherlands antilles and aruba from 1890 to 2013']],
#   ['koningsdag',
#    ['koningsdag or kings day is national holiday in kingdom of netherlands']],
#   ['jounen kwéyòl',
#    ['most widely used instrument besides vocals are tambos drums and are beaten throughout as people speak in creole language and have merry time']],
#   ['oranjegekte',
#    ['oranjegekte orange craze or oranjekoorts orange fever is phenomenon in netherlands that occurs during major sporting events especially international football championships and during koningsdag annual holiday celebrating kings birthday']],
#   ['christmas in basque country',
#    ['they wear caseras because that is what people of mountain wear and holiday used to celebrate peasants who sold their goods in town and came on santo tomas to pay rent to landlords in city']]]]

# %% [markdown]
# ##### Sample26

# %%
context_df.loc[context_df['_id'] == '5a74c85055429916b0164218']
# Out:
#                           _id  \
# 129  5a74c85055429916b0164218
#
#                                                                      question  \
# 129  Born on 6 March 1937, this man was also a citizen of the United Kingdom.
#
#        gold_answers original_pre_answers reduced_pre_answers  \
# 129  alistair grant       british people      alistair grant
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].extended_phrases.values)
# Out:
# id:  ['5a74c85055429916b0164218']
# question:  ['Born on 6 March 1937, this man was also a citizen of the United Kingdom.']
# gold_answer:  ['alistair grant']
# original_pre_answer:  ['british people']
# reduced_pre_answer:  ['alistair grant']
# supporting_facts:  [list([['Alistair Grant', 0], ['British people', 0]])]
# supporting_facts_reduced_context:  [list([['British people', 0], ['Alistair Grant', 0]])]
# question_phrases:  [list([['6 march 1937', 0.2382402917], ['6 march', 0.21589858], ['united kingdom', 0.1869566225], ['citizen', 0.1760124754], ['man', 0.0922168457]])]
# common_phrases:  [list(['citizen', '6 march 1937', 'united kingdom', '6 march'])]
# extended_phrases:  [list(['6 march 1937', 'citizen', '6 march', 'british', 'united kingdom', 'man'])]

# %%
context_df.loc[context_df['_id'] == '5a74c85055429916b0164218']['context'].values.tolist()
# Out:
# [[['vatroslav rožić',
#    ['vatroslav rožić 13 march 1857 – 6 march 1937 was croatian linguist and ethnographer']],
#   ['british people',
#    ['british people or britons are citizens of united kingdom british overseas territories and crown dependencies',
#     'british nationality law governs modern british citizenship and nationality which can be acquired for instance by descent from british nationals',
#     'when used in historical context british or britons can refer to celtic britons indigenous inhabitants of great britain and brittany whose surviving members are modern welsh people cornish people and bretons']],
#   ['alistair grant',
#    ['sir matthew alistair grant 1 2 3 4 6 march 1937 – 21 january 2001 was british businessman']],
#   ['william bonfield',
#    ['william bonfield cbe freng frs born 6 march 1937 is british material scientist and emeritus professor of medical materials in university of cambridge']],
#   ['paul méfano',
# ...

# %%
context_df.loc[context_df['_id'] == '5a74c85055429916b0164218']['reduced_context'].values.tolist()
# Out:
# [[['vatroslav rožić',
#    ['vatroslav rožić 13 march 1857 – 6 march 1937 was croatian linguist and ethnographer']],
#   ['british people',
#    ['british people or britons are citizens of united kingdom british overseas territories and crown dependencies',
#     'british nationality law governs modern british citizenship and nationality which can be acquired for instance by descent from british nationals',
#     'when used in historical context british or britons can refer to celtic britons indigenous inhabitants of great britain and brittany whose surviving members are modern welsh people cornish people and bretons']],
#   ['alistair grant',
#    ['sir matthew alistair grant 1 2 3 4 6 march 1937 – 21 january 2001 was british businessman']],
#   ['william bonfield',
#    ['william bonfield cbe freng frs born 6 march 1937 is british material scientist and emeritus professor of medical materials in university of cambridge']],
#   ['paul méfano',
# ...

# %% [markdown]
# ##### Sample27

# %%
context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4']
# Out:
#                           _id  \
# 149  5adef80b5542993a75d263c4
#
#                                                                                                 question  \
# 149  The 2000 British film Snatch was later adapted into a television series for what streaming service?
#
#     gold_answers original_pre_answers reduced_pre_answers  \
# 149      crackle              netflix             crackle
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].extended_phrases.values)
# Out:
# id:  ['5adef80b5542993a75d263c4']
# question:  ['The 2000 British film Snatch was later adapted into a television series for what streaming service?']
# gold_answer:  ['crackle']
# original_pre_answer:  ['netflix']
# reduced_pre_answer:  ['crackle']
# supporting_facts:  [list([['Snatch (TV series)', 0], ['Snatch (film)', 1]])]
# supporting_facts_reduced_context:  [list([['Snatch (film)', 1], ['Snatch (TV series)', 0]])]
# question_phrases:  [list([['2000 british film snatch', 0.2423100178], ['television series', 0.1936669588], ['2000', 0.1388077346], ['british', 0.1388077346]])]
# common_phrases:  [list(['2000', 'british', 'television series'])]
# extended_phrases:  [list(['television series', '2000 british crime comedy film', 'british', '2000', 'snatch', 'film', '2000 british film snatch'])]

# %%
context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4']['context'].values.tolist()
# Out:
# [[['snatch film',
#    ['snatch stylised as snatch',
#     'is 2000 british crime comedy film written and directed by guy ritchie featuring ensemble cast',
#     'set in london criminal underworld film contains two intertwined plots one dealing with search for stolen diamond other with smalltime boxing promoter jason statham who finds himself under thumb of ruthless gangster alan ford who is ready and willing to have his subordinates carry out severe and sadistic acts of violence']],
#   ['orange is new black',
#    ['orange is new black sometimes abbreviated to oitnb is american comedydrama web television series created by jenji kohan for netflix',
#     'series is based on piper kermans memoir 2010 about her experiences at fci danbury minimumsecurity federal prison',
#     'orange is new black premiered on july 11 2013 on streaming service netflix',
#     'in february 2016 series was renewed for fifth sixth and seventh season',
#     'fifth season was released on june 9 2017',
# ...

# %%
context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4']['reduced_context'].values.tolist()
# Out:
# [[['snatch film',
#    ['snatch stylised as snatch',
#     'is 2000 british crime comedy film written and directed by guy ritchie featuring ensemble cast']],
#   ['snatch tv series',
#    ['snatch is britishamerican television series based on film of same name which debuted on crackle on 16 march 2017']],
#   ['please dont eat daisies',
#    ['essays do not have plot or throughstoryline but book sold so well it was later adapted into film starring doris day and david niven',
#     'film was later adapted into television series starring patricia crowley and mark miller']],
#   ['gilmore girls year in life',
#    ['it is sequel to gilmore girls american comedydrama television series created by amy shermanpalladino and starring lauren graham and alexis bledel which ran from 2000 to 2007 on wb and cw']]]]

# %% [markdown]
# ##### Sample28

# %%
context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb']
# Out:
#                           _id  \
# 172  5ae4f2c75542993aec5ec0fb
#
#                                                                                                                                    question  \
# 172  What airport serviced by American Airlines Shuttle, is also the largest airport in the New England region and 17th busiest in the U.S?
#
#                     gold_answers  \
# 172  logan international airport
#
#                                         original_pre_answers  \
# 172  logan international airport logan international airport
#
#              reduced_pre_answers  \
# 172  logan international airport
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].extended_phrases.values)
# Out:
# id:  ['5ae4f2c75542993aec5ec0fb']
# question:  ['What airport serviced by American Airlines Shuttle, is also the largest airport in the New England region and 17th busiest in the U.S?']
# gold_answer:  ['logan international airport']
# original_pre_answer:  ['logan international airport logan international airport']
# reduced_pre_answer:  ['logan international airport']
# supporting_facts:  [list([['American Airlines Shuttle', 1], ['Logan International Airport', 2]])]
# supporting_facts_reduced_context:  [list([['Logan International Airport', 0]])]
# question_phrases:  [list([['new england region', 0.2070110469], ['american airlines shuttle', 0.2007515148], ['large airport', 0.1959647645], ['american airlines', 0.1776109134], ['17th', 0.1280022696], ['airport', 0.0871039467]])]
# common_phrases:  [list(['american airlines shuttle', '17th', 'american airlines', 'airport', 'large airport', 'new england region'])]
# ...

# %%
context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb']['context'].values.tolist()
# Out:
# [[['kazan international airport',
#    ['kazan international airport russian международный аэропорт казань tatar казан халыкара аэропорты qazan xalıqara aeroportı iata kzn icao uwkd is airport located in tatarstan russia around 25 km southeast of kazan',
#     'it is largest airport in tatarstan and 15th busiest airport in russia',
#     'kazan airport served nearly 38 million citizens of region']],
#   ['pitt meadows airport',
#    ['pitt meadows airport icao cypk is canadian general aviation airport located in southwest of corner of pitt meadows british columbia',
#     'in 2016 it was 17th busiest airport in canada with 109188 aircraft movements and is 4th busiest airport in lower mainland']],
#   ['charlotte douglas international airport',
#    ['charlotte douglas international airport iata clt icao kclt faa lid clt is joint civilmilitary public international airport located in charlotte north carolina united states',
# ...

# %%
context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb']['reduced_context'].values.tolist()
# Out:
# [[['kazan international airport',
#    ['kazan international airport russian международный аэропорт казань tatar казан халыкара аэропорты qazan xalıqara aeroportı iata kzn icao uwkd is airport located in tatarstan russia around 25 km southeast of kazan',
#     'it is largest airport in tatarstan and 15th busiest airport in russia']],
#   ['pitt meadows airport',
#    ['in 2016 it was 17th busiest airport in canada with 109188 aircraft movements and is 4th busiest airport in lower mainland']],
#   ['charlotte douglas international airport',
#    ['established in 1935 as charlotte municipal airport in 1954 airport was renamed douglas municipal airport after former charlotte mayor ben elbert douglas sr airport gained its current name in 1982 and as of september 2017 it is second largest hub for american airlines after dallasfort worth international airport with service to 161 domestic and international destinations',
# ...

# %% [markdown]
# ##### Sample29

# %%
context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f']
# Out:
#                           _id  \
# 273  5a8f69b55542997ba9cb324f
#
#                                                                                             question  \
# 273  What national historic district is located near a village in the town of Philipstown, New York?
#
#                              gold_answers            original_pre_answers  \
# 273  valhalla highlands historic district  glimmerglass historic district
#
#                       reduced_pre_answers  \
# 273  valhalla highlands historic district
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].extended_phrases.values)
# Out:
# id:  ['5a8f69b55542997ba9cb324f']
# question:  ['What national historic district is located near a village in the town of Philipstown, New York?']
# gold_answer:  ['valhalla highlands historic district']
# original_pre_answer:  ['glimmerglass historic district']
# reduced_pre_answer:  ['valhalla highlands historic district']
# supporting_facts:  [list([['Valhalla Highlands Historic District', 0], ['Cold Spring, New York', 0]])]
# supporting_facts_reduced_context:  [list([['Valhalla Highlands Historic District', 0], ['Cold Spring, New York', 0]])]
# question_phrases:  [list([['national historic district', 0.2309401077], ['philipstown new york', 0.2309401077], ['new york', 0.1984108265], ['town', 0.1655809756], ['philipstown', 0.1655809756], ['village', 0.1387081652]])]
# common_phrases:  [list(['new york', 'national historic district', 'philipstown', 'village', 'town'])]
# ...

# %%
context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f']['context'].values.tolist()
# Out:
# [[['arrow rock missouri',
#    ['arrow rock is village in saline county missouri united states located near missouri river',
#     'village has important historical significance related to westward expansion santa fe trail and 19th century artist george caleb bingham',
#     'state’s first state historic site is located here and entire village is part of national historic landmark arrow rock historic district designated by department of interior national park service in 1963',
#     'many structures within village are also individually listed on national register of historic places',
#     'several locations are also certified sites of lewis and clark national historic trail and santa fe national historic trail']],
#   ['greater newport rural historic district',
#    ['greater newport rural historic district is national historic district located near newport giles county virginia',
# ...

# %%
context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f']['reduced_context'].values.tolist()
# Out:
# [[['arrow rock missouri',
#    ['arrow rock is village in saline county missouri united states located near missouri river',
#     'village has important historical significance related to westward expansion santa fe trail and 19th century artist george caleb bingham',
#     'many structures within village are also individually listed on national register of historic places']],
#   ['greater newport rural historic district',
#    ['greater newport rural historic district is national historic district located near newport giles county virginia',
#     'it encompasses total of 737 contributing buildings and 25 contributing structures in rural area near village of newport']],
#   ['gilbert town historic district',
#    ['gilbert town historic district is set of three archaeological sites and national historic district located near rutherfordton rutherford county north carolina']],
#   ['elmwood historic district–west',
# ...

# %% [markdown]
# #### gold_answers  ==  reduced_pre_answers &  original_pre_answers  == gold_answers

# %% [markdown]
# ##### Sample29

# %%
context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028']
# Out:
#                         _id  \
# 5  5a85b2d95542997b5ce40028
#
#                                                                                                      question  \
# 5  Who was known by his stage name Aladin and helped organizations improve their performance as a consultant?
#
#     gold_answers original_pre_answers reduced_pre_answers  \
# 5  eenasul fateh        eenasul fateh       eenasul fateh
#
# ...

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].extended_phrases.values)
# Out:
# id:  ['5a85b2d95542997b5ce40028']
# question:  ['Who was known by his stage name Aladin and helped organizations improve their performance as a consultant?']
# gold_answer:  ['eenasul fateh']
# original_pre_answer:  ['eenasul fateh']
# reduced_pre_answer:  ['eenasul fateh']
# supporting_facts:  [list([['Eenasul Fateh', 0], ['Management consulting', 0]])]
# supporting_facts_reduced_context:  [list([['Eenasul Fateh', 0], ['Management consulting', 0]])]
# question_phrases:  [list([['organization', 0.1786337221], ['aladin', 0.1786337221], ['stage name', 0.1237404775], ['consultant', 0.1068692625], ['performance', 0.0875243115]])]
# common_phrases:  [list(['organization', 'aladin', 'performance', 'consultant', 'stage name'])]
# extended_phrases:  [list(['organization', 'eldee', 'entrepreneur', 'aladin', 'performance', 'consultant', 'management consulting', 'stage name'])]

# %%
context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028']['context'].values.tolist()
# Out:
# [[['james p comer',
#    ['james p comer born james pierpont comer september 25 1934 in east chicago indiana is currently maurice falk professor of child psychiatry at yale child study center and has been since 1976',
#     'he is also associate dean at yale school of medicine',
#     'as one of worlds leading child psychiatrists he is best known for his efforts to improve scholastic performance of children from lowerincome and minority backgrounds which led to founding of comer school development program in 1968',
#     'his program has been used in more than 600 schools in eightytwo school districts',
#     'he is author of ten books including autobiographical maggie’s american dream life and times of black family 1988 leave no child behind preparing todays youth for tomorrows world 2004 and his most recent book what i learned in school reflections on race child development and school reform 2009',
# ...

# %%
context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028']['reduced_context'].values.tolist()
# Out:
# [[['james p comer',
#    ['dr comer has also served as consultant to childrens television workshop sesame workshop which produces sesame street and electric company 1971 tv series']],
#   ['method man', ['he took his stage name from 1979 film method man']],
#   ['indriati iskak',
#    ['for twentysix years she worked with unilever and since 1994 she has been marketing consultant with makki makki']],
#   ['eenasul fateh',
#    ['eenasul fateh bengali ঈনাসুল ফাতেহ born 3 april 1959 also known by his stage name aladin is bangladeshibritish cultural practitioner magician live artist and former international management consultant']],
#   ['mick dj',
#    ['mick batyske known by his stage name mick sometimes styled as mick and formerly mick boogie is american dj and entrepreneur',
#     'as entrepreneur he has invested in various startup companies including localeur in which he is also advisor and consultant']],
#   ['eldee',
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [_id, question, gold_answers, original_pre_answers, reduced_pre_answers, context, reduced_context, context_joint, reduced_context_joint, supporting_facts, supporting_facts_reduced_context, question_phrases, paras_phrases, common_phrases, path_phrases, extended_phrases, kept_para_sent, sp_in_reduced_context_ratio, normalized_answer_in_reduced_context]
# Index: []

# %% [markdown]
# ### Obeservation and action

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
fuzz.ratio("Catherine M Gitau","Catherine Gitau")
# Out:
# 94

# %%
fuzz.ratio("route","road")
# Out:
# 44

# %%
fuzz.partial_ratio("Catherine M. Gitau","Catherine Gitau")
# Out:
# 80

# %%
str2Match = "apple inc"
strOptions = ["Apple Inc.","apple park","apple incorporated","iphone"]
Ratios = process.extract(str2Match,strOptions)
print(Ratios)
# Out:
# [('Apple Inc.', 100), ('apple incorporated', 90), ('apple park', 67), ('iphone', 30)]
