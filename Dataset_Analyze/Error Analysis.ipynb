# %% [markdown]
# ### Original Context Prediction
#
# With original context. <br>

# %%
original_qids =!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/Results/Intermediate_Results/train_answer_longformer_3feebb1a09f9d807dbdae87fda8609e129094a1d/log_longformer_hotpotqa_train_answer_3feebb1a09f9d807dbdae87fda8609e129094a1d_resume.txt" | awk -F "[:\t]" '{ sub("^[ ]+", "", $(NF-6));  print $(NF-6)}'   )

# %%
original_qids
# Out:
# ['5a8b57f25542995d1e6f1371',
#  '5a8c7595554299585d9e36b6',
#  '5a85ea095542994775f606a8',
#  '5adbf0a255429947ff17385a',
#  '5a8e3ea95542995a26add48d',
#  '5abd94525542992ac4f382d2',
#  '5a85b2d95542997b5ce40028',
#  '5a87ab905542996e4f3088c1',
#  '5a7bbb64554299042af8f7cc',
#  '5a8db19d5542994ba4e3dd00',
#  '5a7166395542994082a3e814',
#  '5a877e5d5542993e715abf7d',
#  '5ab3b0bf5542992ade7c6e39',
#  '5ab56e32554299637185c594',
#  '5ab6d09255429954757d337d',
#  '5a75e05c55429976ec32bc5f',
#  '5ab3e45655429976abd1bcd4',
#  '5ab29c24554299449642c932',
#  '5ae0d4c9554299603e418468',
#  '5a8133725542995ce29dcbdb',
#  '5ae7a8175542993210983ed8',
#  '5ae6050f55429929b0807a5e',
#  '5adddccd5542997dc7907069',
#  '5ae2070a5542994d89d5b313',
#  '5ae22b8d554299234fd0440f',
#  '5a722b8655429971e9dc9329',
#  '5adf37a95542995ec70e8f97',
#  '5abd259d55429924427fcf1a',
#  '5a828c8355429966c78a6a50',
#  '5a8a3e745542996c9b8d5e70',
#  '5ac23ff0554299636651994d',
#  '5ae4a3265542995ad6573de5',
# ...

# %%
original_pre_answers=!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/Results/Intermediate_Results/train_answer_longformer_3feebb1a09f9d807dbdae87fda8609e129094a1d/log_longformer_hotpotqa_train_answer_3feebb1a09f9d807dbdae87fda8609e129094a1d_resume.txt" |  awk -F "[:\t]" '{sub("^[ ]+", "", $(NF-3)); sub("[ ]+$", "", $(NF-3));  print $(NF-3)}'   )

# sub("^[ ]+", "") trim leading whitespace
# sub("[ ]+$", "") trim tailing whitespace

# %%
original_pre_answers
# Out:
# ['yes',
#  'united states ambassador',
#  'animorphs',
#  'no',
#  'greenwich village',
#  'yg entertainment',
#  'eenasul fateh',
#  '3677',
#  'terry richardson',
#  'yes',
#  'we’re from kansas',
#  'david weissman',
#  '1999',
#  'yes',
#  '1986 to 2013',
#  '9984',
#  'north atlantic conference',
#  'no',
#  '1953 to 1961',
#  'robert erskine childers',
#  'sergio pérez',
#  'miles tails prower',
#  'isight imac g5',
#  'badly drawn boy',
#  'worlds best goalkeeper',
#  'lee hazlewood',
#  '1838',
#  'yes',
#  'henry j kaiser',
#  'arena of khazan',
#  '2000',
#  'thornhill ontario',
#  'charles nungesser',
#  'no',
#  'letters to cleo',
#  'october 1922',
#  '2000',
#  'world war ii',
#  'no',
#  'city of new york',
#  'scotch collie',
#  'mumbai maharashtra',
#  '1962',
#  'ethiopian sovereignty',
#  'nelson aldrich rockefeller',
#  'firth of forth',
#  'phil spector',
#  'forum',
#  'yes',
#  'english electric canberra',
#  '2009 big 12 conference',
#  '14',
# ...

# %%
original_gold_answers=!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/Results/Intermediate_Results/train_answer_longformer_3feebb1a09f9d807dbdae87fda8609e129094a1d/log_longformer_hotpotqa_train_answer_3feebb1a09f9d807dbdae87fda8609e129094a1d_resume.txt" |  awk -F ':' '{sub("\t ", "", $NF); print $NF}'   )

# %%
original_gold_answers
# Out:
# ['yes',
#  'chief of protocol',
#  'animorphs',
#  'no',
#  'greenwich village new york city',
#  'yg entertainment',
#  'eenasul fateh',
#  '3677 seated',
#  'terry richardson',
#  'yes',
#  'kansas song',
#  'david weissman',
#  '1999',
#  'no',
#  'from 1986 to 2013',
#  '9984',
#  'north atlantic conference',
#  'yes',
#  '1969 until 1974',
#  'robert erskine childers dsc',
#  'pedro rodríguez',
#  'sonic',
#  'keyboard function keys',
#  'badly drawn boy',
#  'worlds best goalkeeper',
#  'barton lee hazlewood',
#  '1838',
#  'yes',
#  'henry j kaiser',
#  'arena of khazan',
#  '2000',
#  'fujioka gunma',
#  'charles eugène',
#  'no',
#  'letters to cleo',
#  'october 1922',
#  '2000',
#  'world war ii',
#  'no',
#  'new york city',
#  'scotch collie',
#  'mumbai',
#  '1962',
#  'sovereignty',
#  'nelson rockefeller',
#  'yellowcraig',
#  'phil spector',
#  'organizations could come together to address global issues',
#  'yes',
#  'english electric canberra',
# ...

# %%
#original_strat=!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/logs/log_longformer_hotpotqa_reduced_train_answer_d7d5adc74a0d0b7ba99a6ee9ef19be0270b17c60_1gpu.txt" |  awk -F ':' '{sub("\t ", "", $NF); print $NF}'   )

# %% [markdown]
# ### Reduced Context Prediction

# %%
reduced_qids =!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/Results/Intermediate_Results/train_answer_longformer_reduced_context_31c4cc322b0ecad9cae3db1d4adfcdc5532f279f/log_longformer_hotpotqa_train_answer_reduced_context_31c4cc322b0ecad9cae3db1d4adfcdc5532f279f.txt" | awk -F "[:\t]" '{ sub("^[ ]+", "", $(NF-6));  print $(NF-6)}'   )

# %%
reduced_qids
# Out:
# ['5a8b57f25542995d1e6f1371',
#  '5a8c7595554299585d9e36b6',
#  '5a85ea095542994775f606a8',
#  '5adbf0a255429947ff17385a',
#  '5a8e3ea95542995a26add48d',
#  '5abd94525542992ac4f382d2',
#  '5a85b2d95542997b5ce40028',
#  '5a87ab905542996e4f3088c1',
#  '5a7bbb64554299042af8f7cc',
#  '5a8db19d5542994ba4e3dd00',
#  '5a7166395542994082a3e814',
#  '5a877e5d5542993e715abf7d',
#  '5ab3b0bf5542992ade7c6e39',
#  '5ab56e32554299637185c594',
#  '5ab6d09255429954757d337d',
#  '5a75e05c55429976ec32bc5f',
#  '5ab3e45655429976abd1bcd4',
#  '5ab29c24554299449642c932',
#  '5ae0d4c9554299603e418468',
#  '5a8133725542995ce29dcbdb',
#  '5ae7a8175542993210983ed8',
#  '5ae6050f55429929b0807a5e',
#  '5adddccd5542997dc7907069',
#  '5ae2070a5542994d89d5b313',
#  '5ae22b8d554299234fd0440f',
#  '5a722b8655429971e9dc9329',
#  '5adf37a95542995ec70e8f97',
#  '5abd259d55429924427fcf1a',
#  '5a828c8355429966c78a6a50',
#  '5a8a3e745542996c9b8d5e70',
#  '5ac23ff0554299636651994d',
#  '5ae4a3265542995ad6573de5',
# ...

# %%
original_qids == reduced_qids
# Out:
# True

# %%
reduced_gold_answers=!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/Results/Intermediate_Results/train_answer_longformer_reduced_context_31c4cc322b0ecad9cae3db1d4adfcdc5532f279f/log_longformer_hotpotqa_train_answer_reduced_context_31c4cc322b0ecad9cae3db1d4adfcdc5532f279f.txt" |  awk -F ':' '{sub("\t ", "", $NF); print $NF}'   )

# %%
reduced_gold_answers
# Out:
# ['yes',
#  'chief of protocol',
#  'animorphs',
#  'no',
#  'greenwich village new york city',
#  'yg entertainment',
#  'eenasul fateh',
#  '3677 seated',
#  'terry richardson',
#  'yes',
#  'kansas song',
#  'david weissman',
#  '1999',
#  'no',
#  'from 1986 to 2013',
#  '9984',
#  'north atlantic conference',
#  'yes',
#  '1969 until 1974',
#  'robert erskine childers dsc',
#  'pedro rodríguez',
#  'sonic',
#  'keyboard function keys',
#  'badly drawn boy',
#  'worlds best goalkeeper',
#  'barton lee hazlewood',
#  '1838',
#  'yes',
#  'henry j kaiser',
#  'arena of khazan',
#  '2000',
#  'fujioka gunma',
#  'charles eugène',
#  'no',
#  'letters to cleo',
#  'october 1922',
#  '2000',
#  'world war ii',
#  'no',
#  'new york city',
#  'scotch collie',
#  'mumbai',
#  '1962',
#  'sovereignty',
#  'nelson rockefeller',
#  'yellowcraig',
#  'phil spector',
#  'organizations could come together to address global issues',
#  'yes',
#  'english electric canberra',
# ...

# %%
reduced_pre_answers=!(grep "pre_answer:" "/xdisk/msurdeanu/fanluo/hotpotQA/Results/Intermediate_Results/train_answer_longformer_reduced_context_31c4cc322b0ecad9cae3db1d4adfcdc5532f279f/log_longformer_hotpotqa_train_answer_reduced_context_31c4cc322b0ecad9cae3db1d4adfcdc5532f279f.txt" |  awk -F "[:\t]" '{sub("^[ ]+", "", $(NF-3)); sub("[ ]+$", "", $(NF-3));  print $(NF-3)}'   )

# %%
reduced_pre_answers
# Out:
# ['yes',
#  'lord high treasurer',
#  'animorphs',
#  'no',
#  'greenwich village',
#  'yg entertainment',
#  'eenasul fateh',
#  '3677',
#  'terry richardson',
#  'yes',
#  'kansas song we’re from kansas',
#  'david weissman',
#  '1999',
#  'yes',
#  '1986 to 2013',
#  '9984',
#  'north atlantic conference',
#  'yes',
#  '1969 until 1974',
#  'henry roth',
#  'sergio pérez',
#  'miles tails prower',
#  'isight imac g5',
#  'badly drawn boy',
#  'worlds best goalkeeper',
#  'lee hazlewood',
#  '1838',
#  'yes',
#  'henry john kaiser',
#  'arena of khazan',
#  '2000',
#  'japanese',
#  'charles nungesser',
#  'no',
#  'letters to cleo',
#  '1923',
#  '2000',
#  'world war ii',
#  'no',
#  'upper manhattan',
#  'scotch collie',
#  'mumbai maharashtra',
#  '1962',
#  'ethiopian sovereignty',
#  '41st',
#  'yellowcraig',
#  'phil spector',
#  'world summit of nobel peace laureates',
#  'yes',
#  'english electric canberra',
#  '2009 big 12 conference football season',
#  '1462',
# ...

# %%
original_gold_answers == reduced_gold_answers
# Out:
# True

# %%
len(list(original_gold_answers))
# Out:
# 7403

# %%
len(list(reduced_gold_answers))
# Out:
# 7403

# %% [markdown]
# ### Compare

# %%
import pandas as pd 
pd.set_option('display.max_columns', None)  
pd.set_option("display.max_colwidth", None)

# %%
prediction_df = pd.DataFrame(list(zip(original_qids, original_gold_answers, original_pre_answers, reduced_pre_answers)), columns=['_id','gold_answers', 'original_pre_answers', 'reduced_pre_answers'])

# %%
prediction_df.shape[0]
# Out:
# 7403

# %%
# predict wrong with original context 
prediction_df.loc[prediction_df['gold_answers'] != prediction_df['original_pre_answers']].shape[0]
# Out:
# 3173

# %%
# predict wrong with reduced context 
prediction_df.loc[prediction_df['gold_answers'] != prediction_df['reduced_pre_answers']].shape[0]
# Out:
# 3413

# %%
# predict different with original or reduced context 
prediction_df.loc[prediction_df['original_pre_answers'] != prediction_df['reduced_pre_answers']].shape[0]
# Out:
# 2419

# %%
# predict wrong with both context and reduced context 
prediction_df.loc[(prediction_df['gold_answers'] != prediction_df['original_pre_answers']) & (prediction_df['gold_answers'] != prediction_df['reduced_pre_answers']) ].shape[0]
# Out:
# 2550

# %%
# predict wrong with both context and reduced context, and predict different
prediction_df.loc[(prediction_df['gold_answers'] != prediction_df['original_pre_answers']) & (prediction_df['gold_answers'] != prediction_df['reduced_pre_answers']) & (prediction_df['original_pre_answers'] != prediction_df['reduced_pre_answers']) ].shape[0]
# Out:
# 933

# %%
prediction_df.loc[(prediction_df['gold_answers'] == prediction_df['reduced_pre_answers']) & (prediction_df['original_pre_answers'] != prediction_df['gold_answers'])].head(15)
# Out:
#                           _id                                 gold_answers  \
# 17   5ab29c24554299449642c932                                          yes
# 18   5ae0d4c9554299603e418468                              1969 until 1974
# 45   5a7d54165542995f4f402256                                  yellowcraig
# 51   5ab84bf555429916710eb01f                                         1462
# 55   5a8a43eb5542996c9b8d5e82                       marion south australia
# 81   5abdf12255429976d4830a2f                                    bob seger
# 87   5a7759fc5542993569682d60                         canary islands spain
# 100  5a85eed75542996432c5713b                              coahuila mexico
# 109  5a8c4c625542995e66a475a1                   b17 flying fortress bomber
# 115  5a887bc0554299206df2b2b6                                          230
# 128  5ae0006755429925eb1afbd3                   san luis obispo california
# ...

# %%
prediction_df.loc[(prediction_df['gold_answers'].str.isnumeric()==False) & (prediction_df['gold_answers'] != prediction_df['reduced_pre_answers']) & (prediction_df['original_pre_answers'] == prediction_df['gold_answers'])]
# Out:
#                            _id                 gold_answers  \
# 28    5a828c8355429966c78a6a50               henry j kaiser
# 35    5abf63f15542997ec76fd3ea                 october 1922
# 50    5a8e1027554299653c1aa15f       2009 big 12 conference
# 52    5a77724455429972597f153e  indianapolis motor speedway
# 72    5ae7e1fc55429952e35ea9cc                       orange
# ...                        ...                          ...
# 7357  5adf6a5c5542995ec70e8ff9           watertown new york
# 7360  5a85cd295542997175ce202b                     athenion
# 7375  5a8d51355542994ba4e3dc6b             chocolatecolored
# 7384  5a84de5f5542991dd0999e07             detroit michigan
# 7388  5a81418455429903bc27b95f                 barbara bush
#
#              original_pre_answers                     reduced_pre_answers
# 28                 henry j kaiser                       henry john kaiser
# 35                   october 1922                                    1923
# ...

# %% [markdown]
# ### Context and Reduced context

# %%
import string 
from pandas.core.common import flatten
def lower(text):
    return text.lower()

def remove_punc(text):
    exclude = set(string.punctuation)
    return ''.join(ch for ch in text if ch not in exclude)

def remove_articles(text):
    return re.sub(r'\b(a|an|the)\b', ' ', text)
 
def basic_normalize(s):
    def white_space_fix(text):
        return ' '.join(text.split())

    def replace_sentence_end(text):
        exclude = set(['.', '?'])
        return ''.join(ch if ch not in exclude  else ',' for ch in str(text))

#     def remove_stop_words(text):
#         all_stopwords = set(nlp.Defaults.stop_words)
#         return ' '.join(word for word in text.split() if word not in all_stopwords) 
    def remove_wh_words(text):
        wh_words = set(["what", "when", 'where', "which", "who", "whom", "whose", "why", "how", "whether",
                        "What", "When", 'Where', "Which", "Who", "Whom", "Whose", "Why", "How", "Whether"])
        return ' '.join(word for word in text.split() if word not in wh_words) 

    return white_space_fix(remove_wh_words(replace_sentence_end(str(s))))

def _normalize_text(s):
    return basic_normalize(remove_articles(remove_punc(lower(str(s)))))

import re
import string
from simple_colors import *
# def findWholeWord(w):
#     return re.compile(r'\b({0})\b'.format(re.escape(w.strip(string.punctuation))), flags=re.IGNORECASE).search
#     # strip(string.punctuation) to remove heading and ending punctuations in the answer, otherwise can not found correctly if heading or ending punctuations appears
    
# def findWord(w, context):
#     if(w == ''):
#         return False
#     if(len(list(re.finditer(str(w), str(context), re.IGNORECASE))) > 0):
#         return True
#     else:
#         return False

# %%
with open('/xdisk/msurdeanu/fanluo/hotpotQA/Data/hotpot_dev_distractor_v1.json', "r", encoding = 'utf-8') as handle:
    data = json.load(handle)
    dev_df = pd.json_normalize(data)

# %%
dev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7405 entries, 0 to 7404
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               7405 non-null   object
#  1   answer            7405 non-null   object
#  2   question          7405 non-null   object
#  3   supporting_facts  7405 non-null   object
#  4   context           7405 non-null   object
#  5   type              7405 non-null   object
#  6   level             7405 non-null   object
# dtypes: object(7)
# memory usage: 405.1+ KB

# %%
true_answer = dev_df['answer'].tolist()
true_answer
# Out:
# ['yes',
#  'Chief of Protocol',
#  'Animorphs',
#  'no',
#  'Greenwich Village, New York City',
#  'YG Entertainment',
#  'Eenasul Fateh',
#  '3,677 seated',
#  'Terry Richardson',
#  'yes',
#  'Kansas Song',
#  'David Weissman',
#  '1999',
#  'no',
#  'from 1986 to 2013',
#  '9,984',
#  'the North Atlantic Conference',
#  'yes',
#  '1969 until 1974',
#  'Robert Erskine Childers DSC',
#  'Pedro Rodríguez',
#  'Sonic',
#  'keyboard function keys',
#  'Badly Drawn Boy',
#  "World's Best Goalkeeper",
#  'Barton Lee Hazlewood',
#  '1838',
#  'yes',
#  'Henry J. Kaiser',
#  'Arena of Khazan',
#  '2000',
#  'Fujioka, Gunma',
#  'Charles Eugène',
#  'no',
#  'Letters to Cleo',
#  'October 1922',
#  '2000',
#  'World War II',
#  'no',
#  'New York City',
#  'Scotch Collie',
#  'Mumbai',
#  '1962',
#  'sovereignty',
#  'Nelson Rockefeller',
#  'Yellowcraig',
#  'Phil Spector',
#  'Organizations could come together to address global issues',
#  'yes',
#  'English Electric Canberra',
# ...

# %%
# find out the missing 2 QA, 7405-7403=2, the first diff is from 3667, which cause misalignment
for i in range(len(list(original_gold_answers))):
    if(_normalize_text(original_gold_answers[i]) != _normalize_text(true_answer[i])):
        print(i, _normalize_text(original_gold_answers[i]), _normalize_text(true_answer[i]))
# Out:
# 3667 for crafting and voting on legislation
# 3668 empire of japan for crafting and voting on legislation
# 3669 pygmy chimpanzee empire of japan
# 3670 june 4 1931 pygmy chimpanzee
# 3671 10 years june 4 1931
# 3672 no 10 years
# 3674 us army no
# 3675 national basketball development league us army
# 3676 novel national basketball development league
# 3677 erodium novel
# 3678 harry lillis bing crosby jr erodium
# 3679 bob hill harry lillis bing crosby jr
# 3680 quasimodo bob hill
# 3681 300 quasimodo
# 3682 rivaldo of milan 300
# 3683 that darn cat rivaldo of milan
# 3684 yes that darn cat
# 3686 beyond clouds yes
# 3687 robert thornby beyond clouds
# 3688 novel with key robert thornby
# 3689 st louis missouri novel with key
# 3690 cha cha cohen were band formed in 1994 st louis missouri
# 3691 life cha cha cohen were band formed in 1994
# 3692 1989 life
# 3693 lynwood 1989
# 3694 shock troops lynwood
# 3695 1993 shock troops
# 3696 centreduquébec 1993
# ...

# %%
true_answer[3667]
# Out:
# 'The The'

# %%
true_answer[5470]
# Out:
# '!!!'

# %%
dev_df.drop([3667, 5470]) in next cell can only run once

# %%
dev_df.drop([3667, 5470], inplace=True)   # can only run once

# %%
true_answer = dev_df['answer'].tolist()
for i in range(len(list(original_gold_answers))):
    if(_normalize_text(original_gold_answers[i]) != _normalize_text(true_answer[i])):
        print(i, original_gold_answers[i],  true_answer[i])

# %%
dev_df.iloc[3667]
# Out:
# _id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   
# ...

# %%
with open('/xdisk/msurdeanu/fanluo/hotpotQA/Data/reduced_questions/hotpot_reduced_context_04-08-2021-01:12:53/hotpot_dev_reduced_context_coref_fuzzy.json', "r", encoding = 'utf-8') as handle:
    data = json.load(handle)
    dev_reduced_context_df = pd.json_normalize(data)

# %%
dev_reduced_context_df.iloc[3667]['answer']
# Out:
# 'The The'

# %%
dev_reduced_context_df.iloc[5470]['answer']
# Out:
# '!!!'

# %%
dev_reduced_context_df.drop([3667, 5470]) in next cell can only run once

# %%
dev_reduced_context_df.drop([3667, 5470], inplace=True)

# %%
dev_reduced_context_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7403 entries, 0 to 7404
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   level             7403 non-null   object
#  1   type              7403 non-null   object
#  2   context           7403 non-null   object
#  3   answer            7403 non-null   object
#  4   _id               7403 non-null   object
#  5   question          7403 non-null   object
#  6   kept_para_sent    7403 non-null   object
#  7   supporting_facts  7403 non-null   object
# dtypes: object(8)
# memory usage: 520.5+ KB

# %%
context_df = dev_df.join(dev_reduced_context_df, rsuffix='_reduced_context')

# %%
context_df = context_df.set_index('_id').join(prediction_df.set_index('_id'))   
# simply join cause missing 2 gold_answers, original_pre_answers, and reduced_pre_answers, and then cause misalignment, might because of the previous drop
# after join 'on', there is no '_id' field anymore

# %%
context_df['context_flattened'] = context_df['context'].map(lambda x: list(flatten(x)))
context_df['context_joint'] = context_df['context_flattened'].map(lambda x: _normalize_text(" ".join(x)))

# %%
context_df['reduced_context'] = context_df['context_reduced_context'] 
context_df['reduced_context_flattened'] = context_df['reduced_context'].map(lambda x: list(flatten(x)))
context_df['reduced_context_joint'] = context_df['reduced_context_flattened'].map(lambda x: _normalize_text(" ".join(x)))

# %%
context_df=context_df.loc[:, ['_id_reduced_context', 'question', 'gold_answers', 'original_pre_answers','reduced_pre_answers', 'context', 'reduced_context', 'context_joint', 'reduced_context_joint', 'supporting_facts', 'supporting_facts_reduced_context', #'question_phrases', 'paras_phrases', 'common_phrases', 'path_phrases', 'extended_phrases', 'sp_in_reduced_context_ratio',
'kept_para_sent']]  
context_df.rename(columns={"_id_reduced_context": "_id"}, inplace=True)

# %%
context_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7403 entries, 5a8b57f25542995d1e6f1371 to 5ac132a755429964131be17c
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   _id                               7403 non-null   object
#  1   question                          7403 non-null   object
#  2   gold_answers                      7403 non-null   object
#  3   original_pre_answers              7403 non-null   object
#  4   reduced_pre_answers               7403 non-null   object
#  5   context                           7403 non-null   object
#  6   reduced_context                   7403 non-null   object
#  7   context_joint                     7403 non-null   object
#  8   reduced_context_joint             7403 non-null   object
#  9   supporting_facts                  7403 non-null   object
#  10  supporting_facts_reduced_context  7403 non-null   object
# ...

# %%
context_df['normalized_answer_in_reduced_context'] = context_df.apply(lambda row: 
 len(list(re.finditer(_normalize_text(row['gold_answers']), row['reduced_context_joint'], re.IGNORECASE)) ) > 0 , axis = 1) 

# context_df['normalized_answer_in_reduced_context'] = context_df.apply(lambda row:  findWord(_normalize_text(row['gold_answers']), _normalize_text(row['reduced_context_joint'])) == True , axis = 1)

# %%
context_df['normalized_answer_in_reduced_context'].value_counts()
# Out:
# True     6569
# False     834
# Name: normalized_answer_in_reduced_context, dtype: int64

# %% [markdown]
# ### Samples

# %%
# ### run graph_hotpotqa to enable calling reduce_context_with_phares_graph() to check the details of question_phrases, common_phrases, etc that are used to construct reduced_context

# #### IMPORTANT: need to maunally change kernel to 'spacy' first

# import sys
# sys.path.insert(-1, '/xdisk/msurdeanu/fanluo/miniconda3/lib/python3.8/site-packages')      #for module named 'nbformat'
# %run /home/u32/fanluo/Jupyter/experiments/transformers/graph_hotpotqa.ipynb

# %% [markdown]
# #### gold_answers  !=  reduced_pre_answers &  original_pre_answers  == gold_answers

# %%
# predict correct with original context, but wrong with reduced context 
prediction_df.loc[(prediction_df['gold_answers'] != prediction_df['reduced_pre_answers']) & (prediction_df['original_pre_answers'] == prediction_df['gold_answers'])]
# Out:
#                            _id                 gold_answers  \
# 28    5a828c8355429966c78a6a50               henry j kaiser
# 35    5abf63f15542997ec76fd3ea                 october 1922
# 50    5a8e1027554299653c1aa15f       2009 big 12 conference
# 52    5a77724455429972597f153e  indianapolis motor speedway
# 72    5ae7e1fc55429952e35ea9cc                       orange
# ...                        ...                          ...
# 7360  5a85cd295542997175ce202b                     athenion
# 7375  5a8d51355542994ba4e3dc6b             chocolatecolored
# 7384  5a84de5f5542991dd0999e07             detroit michigan
# 7388  5a81418455429903bc27b95f                 barbara bush
# 7390  5ae81b895542997ec272770c                         1876
#
#              original_pre_answers                     reduced_pre_answers
# 28                 henry j kaiser                       henry john kaiser
# 35                   october 1922                                    1923
# ...

# %%
prediction_df.loc[(prediction_df['gold_answers'] != prediction_df['reduced_pre_answers']) & (prediction_df['original_pre_answers'] == prediction_df['gold_answers'])].head(16)
# Out:
#                           _id                 gold_answers  \
# 28   5a828c8355429966c78a6a50               henry j kaiser
# 35   5abf63f15542997ec76fd3ea                 october 1922
# 50   5a8e1027554299653c1aa15f       2009 big 12 conference
# 52   5a77724455429972597f153e  indianapolis motor speedway
# 72   5ae7e1fc55429952e35ea9cc                       orange
# 86   5ae005b555429942ec259bec                         1866
# 113  5a7a455c5542994f819ef1a7           george archainbaud
# 132  5a80071f5542992bc0c4a684             crystal dynamics
# 141  5ac2d1d755429921a00ab053                roberta vinci
# 155  5a906a685542990a9849362e                       brazil
# 159  5ab341f755429969a97a8114                         1989
# 160  5a8325b35542990548d0b18f          kathryn jean martin
# 170  5a8b987f5542997f31a41d7a                  c w grafton
# 178  5a74c85055429916b0164218               alistair grant
# 190  5add673e5542992ae4cec54d        oregon ducks football
# ...

# %% [markdown]
# ##### Sample1

# %%
example = context_df.loc[context_df['_id'] == '5a77724455429972597f153e']

# %%
print(black("id: ", ['bold']), example._id.values)
print(black("question: ", ['bold']), example.question.values)
print(black("gold_answer: ", ['bold']), example.gold_answers.values)
print(black("original_pre_answer: ", ['bold']), example.original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), example.reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), example.supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), example.supporting_facts_reduced_context.values)
# Out:
# id:  ['5a77724455429972597f153e']
# question:  ['What race track in the midwest hosts a 500 mile race eavery May?']
# gold_answer:  ['indianapolis motor speedway']
# original_pre_answer:  ['indianapolis motor speedway']
# reduced_pre_answer:  ['darlington raceway']
# supporting_facts:  [list([['1957 Indianapolis 500', 0], ['Indianapolis Motor Speedway', 0]])]
# supporting_facts_reduced_context:  [list([])]

# %%
example['context'].values.tolist()
# Out:
# [[['Subway 400',
#    ['The Subway 400 was the second race of the NASCAR Winston Cup Series season until 2004, held a week after the Daytona 500.',
#     ' This 400-mile (644\xa0km) annual race was sponsored by Subway and was held at North Carolina Speedway ("The Rock") since 1966.',
#     ' From 1966 to 1995, a 500-mile (805-km) race was held; the race was known as the Peach Blossom 500 (1966), the Carolina 500 (1967–1985), and the Goodwrench 500 (1986–1995).',
#     ' In 1996, the race was shortened to its current distance of 400 miles; the 400 mile race was called the Goodwrench Service 400 (1996–1997), the GM Goodwrench Service Plus 400 (1998), the Dura Lube/Big K 400 (1999), the Dura Lube/Kmart 400 (2000), the Dura Lube 400 (2001), and the Subway 400 (2002–2004).']],
#   ['Carolina Dodge Dealers 400',
#    ['The Carolina Dodge Dealers 400 was the annual spring NASCAR Sprint Cup race held at Darlington Raceway in Darlington, South Carolina, USA.',
# ...

# %%
example['reduced_context'].values.tolist()
# Out:
# [[['Subway 400',
#    ['The Subway 400 was the second race of the NASCAR Winston Cup Series season until 2004, held a week after the Daytona 500.',
#     ' This 400-mile (644\xa0km) annual race was sponsored by Subway and was held at North Carolina Speedway ("The Rock") since 1966.',
#     ' From 1966 to 1995, a 500-mile (805-km) race was held; the race was known as the Peach Blossom 500 (1966), the Carolina 500 (1967–1985), and the Goodwrench 500 (1986–1995).',
#     ' In 1996, the race was shortened to its current distance of 400 miles; the 400 mile race was called the Goodwrench Service 400 (1996–1997), the GM Goodwrench Service Plus 400 (1998), the Dura Lube/Big K 400 (1999), the Dura Lube/Kmart 400 (2000), the Dura Lube 400 (2001), and the Subway 400 (2002–2004).']],
#   ['Carolina Dodge Dealers 400',
#    ['The Carolina Dodge Dealers 400 was the annual spring NASCAR Sprint Cup race held at Darlington Raceway in Darlington, South Carolina, USA.',
# ...

# %%
example['reduced_context_joint'].values[0]
# Out:
# 'subway 400 subway 400 was second race of nascar winston cup series season until 2004 held week after daytona 500 this 400mile 644 km annual race was sponsored by subway and was held at north carolina speedway rock since 1966 from 1966 to 1995 500mile 805km race was held race was known as peach blossom 500 1966 carolina 500 1967–1985 and goodwrench 500 1986–1995 in 1996 race was shortened to its current distance of 400 miles 400 mile race was called goodwrench service 400 1996–1997 gm goodwrench service plus 400 1998 dura lubebig k 400 1999 dura lubekmart 400 2000 dura lube 400 2001 and subway 400 2002–2004 carolina dodge dealers 400 carolina dodge dealers 400 was annual spring nascar sprint cup race held at darlington raceway in darlington south carolina usa 100 mi race was held in may at track in 1952 however event did not become regular one on nascar schedule until 1957 as 300 mi race in convertible division known as rebel 300 in 1966 race was expanded to 400 mi and in 1973 to 500
# ...

# %%
list(re.finditer(_normalize_text(example['gold_answers'].values[0]), example['reduced_context_joint'].values[0], re.IGNORECASE))
# Out:
# []

# %% [markdown]
# ##### Sample2

# %%
context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b'].supporting_facts_reduced_context.values)

# print("question_phrases: ", context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b'].question_phrases.values)
# print("common_phrases: ", context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b'].common_phrases.values)
# print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a85cd295542997175ce202b']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample3

# %%
context_df.loc[context_df['_id'] == '5a8d51355542994ba4e3dc6b']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5a8d51355542994ba4e3dc6b']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5a8d51355542994ba4e3dc6b'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a8d51355542994ba4e3dc6b'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a8d51355542994ba4e3dc6b'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a8d51355542994ba4e3dc6b'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5a8d51355542994ba4e3dc6b'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5a8d51355542994ba4e3dc6b'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5a8d51355542994ba4e3dc6b']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a8d51355542994ba4e3dc6b']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample4

# %%
context_df.loc[context_df['_id'] == '5a84de5f5542991dd0999e07']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5a84de5f5542991dd0999e07']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5a84de5f5542991dd0999e07'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a84de5f5542991dd0999e07'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a84de5f5542991dd0999e07'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a84de5f5542991dd0999e07'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5a84de5f5542991dd0999e07'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5a84de5f5542991dd0999e07'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5a84de5f5542991dd0999e07']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a84de5f5542991dd0999e07']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample5

# %%
context_df.loc[context_df['_id'] == '5a81418455429903bc27b95f']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5a81418455429903bc27b95f']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5a81418455429903bc27b95f'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a81418455429903bc27b95f'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a81418455429903bc27b95f'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a81418455429903bc27b95f'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5a81418455429903bc27b95f'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5a81418455429903bc27b95f'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5a81418455429903bc27b95f']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a81418455429903bc27b95f']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample6

# %%
context_df.loc[context_df['_id'] == '5ae81b895542997ec272770c']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5ae81b895542997ec272770c']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5ae81b895542997ec272770c'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5ae81b895542997ec272770c'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5ae81b895542997ec272770c'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5ae81b895542997ec272770c'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5ae81b895542997ec272770c'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5ae81b895542997ec272770c'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5ae81b895542997ec272770c']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5ae81b895542997ec272770c']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample7

# %%
context_df.loc[context_df['_id'] == '5abf63f15542997ec76fd3ea']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5abf63f15542997ec76fd3ea']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5abf63f15542997ec76fd3ea'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5abf63f15542997ec76fd3ea'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5abf63f15542997ec76fd3ea'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5abf63f15542997ec76fd3ea'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5abf63f15542997ec76fd3ea'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5abf63f15542997ec76fd3ea'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5abf63f15542997ec76fd3ea']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5abf63f15542997ec76fd3ea']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample8

# %%
context_df.loc[context_df['_id'] == '5a7a455c5542994f819ef1a7']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5a7a455c5542994f819ef1a7']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5a7a455c5542994f819ef1a7'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a7a455c5542994f819ef1a7'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a7a455c5542994f819ef1a7'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a7a455c5542994f819ef1a7'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5a7a455c5542994f819ef1a7'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5a7a455c5542994f819ef1a7'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5a7a455c5542994f819ef1a7']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a7a455c5542994f819ef1a7']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample9

# %%
context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a80071f5542992bc0c4a684']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample10

# %%
context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5ac2d1d755429921a00ab053']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample11

# %%
context_df.loc[context_df['_id'] == '5a906a685542990a9849362e']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5a906a685542990a9849362e']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5a906a685542990a9849362e'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5a906a685542990a9849362e']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a906a685542990a9849362e']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample12

# %%
context_df.loc[context_df['_id'] == '5a8325b35542990548d0b18f']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5a8325b35542990548d0b18f']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5a8325b35542990548d0b18f'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a8325b35542990548d0b18f'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a8325b35542990548d0b18f'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a8325b35542990548d0b18f'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5a8325b35542990548d0b18f'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5a8325b35542990548d0b18f'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5a8325b35542990548d0b18f']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a8325b35542990548d0b18f']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample13

# %%
context_df.loc[context_df['_id'] == '5a8b987f5542997f31a41d7a']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5a8b987f5542997f31a41d7a']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5a8b987f5542997f31a41d7a'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a8b987f5542997f31a41d7a'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a8b987f5542997f31a41d7a'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a8b987f5542997f31a41d7a'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5a8b987f5542997f31a41d7a'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5a8b987f5542997f31a41d7a'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5a8b987f5542997f31a41d7a']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a8b987f5542997f31a41d7a']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample14

# %%
context_df.loc[context_df['_id'] == '5a74c85055429916b0164218']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5a74c85055429916b0164218']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5a74c85055429916b0164218']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a74c85055429916b0164218']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample15

# %%
context_df.loc[context_df['_id'] == '5ae057fd55429945ae959328']

# %%
print(black("id: ", ['bold']), context_df.loc[context_df['_id'] == '5ae057fd55429945ae959328']._id.values)
print(black("question: ", ['bold']), context_df.loc[context_df['_id'] == '5ae057fd55429945ae959328'].question.values)
print(black("gold_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5ae057fd55429945ae959328'].gold_answers.values)
print(black("original_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5ae057fd55429945ae959328'].original_pre_answers.values)
print(black("reduced_pre_answer: ", ['bold']), context_df.loc[context_df['_id'] == '5ae057fd55429945ae959328'].reduced_pre_answers.values)
print(black("supporting_facts: ", ['bold']), context_df.loc[context_df['_id'] == '5ae057fd55429945ae959328'].supporting_facts.values)
print(black("supporting_facts_reduced_context: ", ['bold']), context_df.loc[context_df['_id'] == '5ae057fd55429945ae959328'].supporting_facts_reduced_context.values)

# %%
context_df.loc[context_df['_id'] == '5ae057fd55429945ae959328']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5ae057fd55429945ae959328']['reduced_context'].values.tolist()

# %% [markdown]
# #### gold_answers  !=  reduced_pre_answers &  original_pre_answers  != gold_answers

# %% [markdown]
# ##### Sample17

# %%
context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a8e3ea95542995a26add48d']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample18

# %%
context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a87ab905542996e4f3088c1']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample19

# %%
context_df.loc[context_df['_id'] == '5a7166395542994082a3e814']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a7166395542994082a3e814'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5a7166395542994082a3e814']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a7166395542994082a3e814']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample20

# %%
context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5ab6d09255429954757d337d']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample21

# %%
context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5ae7a8175542993210983ed8']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample22

# %%
context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5ae22b8d554299234fd0440f']['reduced_context'].values.tolist()

# %% [markdown]
# #### gold_answers  ==  reduced_pre_answers &  original_pre_answers  != gold_answers

# %%
context_df.loc[ (context_df['gold_answers'] == context_df['reduced_pre_answers']) & (context_df['original_pre_answers'] != context_df['gold_answers']) &(context_df['supporting_facts_reduced_context'] == context_df['supporting_facts'])]['_id']

# %% [markdown]
# ##### Sample23

# %%
context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a7bbb64554299042af8f7cc']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample24

# %%
context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5ab3e45655429976abd1bcd4']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample25

# %%
context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5ae7e1fc55429952e35ea9cc']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample26

# %%
context_df.loc[context_df['_id'] == '5a74c85055429916b0164218']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a74c85055429916b0164218'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5a74c85055429916b0164218']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a74c85055429916b0164218']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample27

# %%
context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5adef80b5542993a75d263c4']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample28

# %%
context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5ae4f2c75542993aec5ec0fb']['reduced_context'].values.tolist()

# %% [markdown]
# ##### Sample29

# %%
context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a8f69b55542997ba9cb324f']['reduced_context'].values.tolist()

# %% [markdown]
# #### gold_answers  ==  reduced_pre_answers &  original_pre_answers  == gold_answers

# %% [markdown]
# ##### Sample29

# %%
context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028']

# %%
print("id: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028']._id.values)
print("question: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].question.values)
print("gold_answer: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].gold_answers.values)
print("original_pre_answer: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].original_pre_answers.values)
print("reduced_pre_answer: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].reduced_pre_answers.values)
print("supporting_facts: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].supporting_facts.values)
print("supporting_facts_reduced_context: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].supporting_facts_reduced_context.values)
print("question_phrases: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].question_phrases.values)
print("common_phrases: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].common_phrases.values)
print("extended_phrases: ", context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028'].extended_phrases.values)

# %%
context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028']['context'].values.tolist()

# %%
context_df.loc[context_df['_id'] == '5a85b2d95542997b5ce40028']['reduced_context'].values.tolist()

# %% [markdown]
# ### Obeservation and action

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
fuzz.ratio("Catherine M Gitau","Catherine Gitau")

# %%
fuzz.ratio("route","road")

# %%
fuzz.partial_ratio("Catherine M. Gitau","Catherine Gitau")

# %%
str2Match = "apple inc"
strOptions = ["Apple Inc.","apple park","apple incorporated","iphone"]
Ratios = process.extract(str2Match,strOptions)
print(Ratios)
